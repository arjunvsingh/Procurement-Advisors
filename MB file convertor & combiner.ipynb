# %%
from tkinter import*
from tkinter import filedialog as fd
from tkinter import messagebox
from tkinter import Radiobutton
from tkinter.ttk import*
import pandas as pd
import numpy as np
import os
import datetime
#from WWGFunctions import*
#dfreview = []
# Please ask Xing if you have questions
class MasterBenchmark:

	def __init__(self):
#		self.dfv = []
		window=Tk() # Create a window
		window.title("Master Benchmark Convertor & Combiner (PA - MBCC)") #Set title


		frame1=Frame(window).grid(row=1,columnspan=3,sticky=EW)

		frame2=Frame(window).grid(row=1, column=4)

		text=Text(frame2)
		text.grid(row=1,rowspan=14,column=4)


		# Create labels
        
		Label(frame1, text="Input Benchmark File").grid(row=1, column=1, sticky= W)
		Label(frame1, text="Sheet name for <Item Detail>").grid(row=2, column=1, sticky= W)
		Label(frame1, text="Sheet name for <Excluded>").grid(row=3, column=1, sticky= W)
		Label(frame1, text="Output File(Master Benchmark Format) Location").grid(row=4, column=1, sticky= W)
		Label(frame1, text="Output File Name").grid(row=5, column=1, sticky= W)
		Label(frame1, text="Customer Name").grid(row=6, column=1, sticky= W)
		Label(frame1, text="Project Name").grid(row=7, column=1, sticky= W)
		Label(frame1, text="PA Vendor").grid(row=8, column=1, sticky= W)
		Label(frame1, text="Spend of SKU's not meeting threshold").grid(row=9, column=1, sticky= W)
		Label(frame1, text="Number of SKU's not meeting threshold").grid(row=10, column=1, sticky= W)
		Label(frame1, text="Location").grid(row=11, column=1, sticky= W)
		Label(frame1, text="Date of Benchmark (Format: YYYY-MM-DD)").grid(row=12, column=1, sticky= W)
		Label(frame1, text="Type of Benchmarking?").grid(row=13, column=1, sticky= W)
		Label(frame1, text="Switch data between columns of Incumbent Distributor name and Incumbent Manufactor name ?").grid(row=14, column=1, sticky= W)
		Label(frame1, text="Switch data between columns of Incumbent Distributor number and Incumbent Manufactor number ?").grid(row=15, column=1, sticky= W)
		Label(frame1, text="Incumbent Distributor name (add to the blank cells under this column in output file)").grid(row=16, column=1, sticky= W)
        
		Label(frame1, text="").grid(row=17,column=1, sticky= W)        
        
		Label(frame1, text="Input Folder Location for all Master-Benchmark Format Files").grid(row=20,column=1, sticky= W)
		Label(frame1, text="Output Folder").grid(row=21,column=1, sticky= W)
		Label(frame1, text="Output File Name").grid(row=22,column=1, sticky= W)
#		Label(frame1, text="Sheet Name for Output File").grid(row=23,column=1, sticky= W)
        
		Label(frame1, text="To combine a mix of Excel and CSV master benchmark files (either or both) in one folder is acceptable >>>>>>").grid(row=24,column=1, sticky= W)

        # Create Button
		Button(frame1,text="Select File",command=self.BMFilePath).grid(row=1,column=3,sticky=EW)
		Button(frame1,text="Choose Output Location",command=self.MBFilePath).grid(row=4,column=3)
        
		Button(frame1,text="Select Input Folder",command=self.MBCombinedInputFolderPath).grid(row=20,column=3,sticky=EW)
		Button(frame1,text="Choose Output Location",command=self.MBCombinedOutputFolderPath).grid(row=21,column=3)
		Button(frame1,text="Combine",command=self.MBFileCombiner).grid(row=24,column=3)
        
		#Create radiobutton
#		self.radio=IntVar()
#		self.r1 = Radiobutton(frame1,text="Internal", variable=self.radio,value=0)
#		self.r1.grid(row=13,column=2, sticky=E)
#		self.r2 = Radiobutton(frame1,text="External", variable=self.radio,value=1)
#		self.r2.grid(row=13,column=3)

#		self.r1.deselect()
		self.c7 = Combobox(window,justify = RIGHT)
		self.c7['values'] = ('External','Internal')
#		self.c7.current('b')
#		self.c7.set('Excluded')
		self.c7.grid(row=13,column=2,sticky=E)

		self.radio2 =IntVar()
		self.r3 = Radiobutton(frame1,text="No", variable=self.radio2,value=0)
		self.r3.grid(row=14,column=2, sticky=E)
		self.r4 = Radiobutton(frame1,text="Yes", variable=self.radio2,value=1)
		self.r4.grid(row=14,column=3)   

		self.radio3 =IntVar()
		self.r5 = Radiobutton(frame1,text="No", variable=self.radio3,value=0)
		self.r5.grid(row=15,column=2, sticky=E)
		self.r6 = Radiobutton(frame1,text="Yes", variable=self.radio3,value=1)
		self.r6.grid(row=15,column=3)  

		# Create entries
		self.InputBenchmarkFileVar = StringVar()
		self.e1= Entry(window, textvariable = self.InputBenchmarkFileVar, justify = RIGHT)
		self.e1.grid(row=1,column=2,sticky=E)

#		self.WhichSheetVar = StringVar()
#		self.e2 = Entry(window, textvariable =self.WhichSheetVar, justify = RIGHT)
#		self.e2.grid(row=2,column=2,sticky=E)
#		self.e2.insert(0,'Item Detail')
        
#		self.incumbentNameVar = StringVar()
#		self.e3 = Entry(window, textvariable = self.incumbentNameVar, justify = RIGHT)
#		self.e3.grid(row=3,column=2,sticky=E)
#		self.e3.insert(0,'Excluded')

		self.c2 = Combobox(window,justify = RIGHT)
		self.c2['values'] = ('Item Detail','ItemDetail.Confidential')
#		self.c2.current('b')
		self.c2.set('Item Detail')
		self.c2.grid(row=2,column=2,sticky=E)
    
		self.c3 = Combobox(window,justify = RIGHT)
		self.c3['values'] = ('Excluded','Excluded.Confidential')
#		self.c3.current('b')
		self.c3.set('Excluded')
		self.c3.grid(row=3,column=2,sticky=E)
        
		self.OutputConvertedFileFolderVar = StringVar()
		self.e4 = Entry(window,textvariable=self.OutputConvertedFileFolderVar,justify = RIGHT)
		self.e4.grid(row=4,column=2,sticky=E)

        
		self.projectNameVar=StringVar()
		self.e5 = Entry(window,textvariable=self.projectNameVar,justify = RIGHT)
		self.e5.grid(row=5,column=2,sticky=E)
		self.e5.insert(0,'OutputFile_MB')		

		self.paVendorVar=StringVar()
		self.e6 = Entry(window,textvariable=self.paVendorVar,justify = RIGHT)
		self.e6.grid(row=6,column=2,sticky=E)

		self.nonBenchmarkedSpendVar=StringVar()
		self.e7 = Entry(window,textvariable=self.nonBenchmarkedSpendVar,justify = RIGHT)
		self.e7.grid(row=7,column=2,sticky=E)
        
#		self.nonBenchmarkedLinesVar=StringVar()
#		self.e8 = Entry(window,textvariable=self.nonBenchmarkedLinesVar,justify = RIGHT)
#		self.e8.grid(row=8,column=2,sticky=E)

		self.c1 = Combobox(window,justify = RIGHT)
		self.c1['values'] = ('WWG','AIT','FNL',"GBE")
#		self.c1.current('b')
		self.c1.grid(row=8,column=2,sticky=E)

		self.datesVar=StringVar()
		self.e9 = Entry(window,textvariable=self.datesVar,justify = RIGHT)
		self.e9.grid(row=9,column=2,sticky=E)

		self.datesVar=StringVar()
		self.e10= Entry(window,textvariable=self.datesVar,justify = RIGHT)
		self.e10.grid(row=10,column=2,sticky=E)
        
		self.datesVar=StringVar()
		self.e11= Entry(window,textvariable=self.datesVar,justify = RIGHT)
		self.e11.grid(row=11,column=2,sticky=E)

		self.datesVar=StringVar()
		self.e12= Entry(window,textvariable=self.datesVar,justify = RIGHT)
		self.e12.grid(row=12,column=2,sticky=E)
        
        
		self.datesVar=StringVar()
		self.e12= Entry(window,textvariable=self.datesVar,justify = RIGHT)
		self.e12.grid(row=12,column=2,sticky=E)
        
		self.datesVar=StringVar()
		self.e16= Entry(window,textvariable=self.datesVar,justify = RIGHT)
		self.e16.grid(row=16,column=2,sticky=E)
        
        
		self.MBFileLocationVar=StringVar()
		self.e20= Entry(window,textvariable=self.MBFileLocationVar,justify = RIGHT)
		self.e20.grid(row=20,column=2,sticky=E)
        
		self.OutputFolderVar=StringVar()
		self.e21= Entry(window,textvariable=self.OutputFolderVar,justify = RIGHT)
		self.e21.grid(row=21,column=2,sticky=E)
        
		self.OutputFileNameVar=StringVar()
		self.e22= Entry(window,textvariable=self.OutputFileNameVar,justify = RIGHT)
		self.e22.grid(row=22,column=2,sticky=E)

#		self.SheetNameOutputVar=StringVar()
#		self.e23= Entry(window,textvariable=self.SheetNameOutputVar,justify=RIGHT)
#		self.e23.grid(row=23,column=2,sticky=E)
#		self.e23.insert(0,'Master Template')
        
#		self.radio9 =IntVar()
#		self.r8 = Radiobutton(frame1,text="To Combine Excel Files", variable=self.radio9,value=0)
#		self.r8.grid(row=24,column=1, sticky=E)
#		self.r9 = Radiobutton(frame1,text="To Combine CSV Files", variable=self.radio9,value=1)
#		self.r9.grid(row=24,column=2)   
        
		self.InputBenchmarkFileVar = StringVar()
		self.e1= Entry(window, textvariable = self.InputBenchmarkFileVar, justify = RIGHT)
		self.e1.grid(row=1,column=2,sticky=E)        
		# Create Button
#		Button(frame1,text="MB File Path",command=self.MBFilePath).grid(row=1,column=3)
#		Button(frame1,text="BM File Path",command=self.BMFilePath).grid(row=2,column=3)

		# Create Button Call back

		Button(window, text="Export File",command=self.dftoExcel).grid(row=16,column=3, sticky=EW)
        
		Button(window, text="Recheck Duplicate Columns",command=self.duplicateColumnsCheck).grid(row=2,column=3, sticky=EW)



		window.mainloop() # Create an event loop

	def BMFilePath(self):
		from tkinter import Radiobutton
		from tkinter import messagebox
		self.InputBMFileName = fd.askopenfilename()
		self.InputBenchmarkFileVar.set(self.InputBMFileName)
#	self.rvalue1= self.radio.get()
#	#print("r1: ",self.rvalue1)
#	self.rvalue2= self.r2.get()

		self.e6.delete(0,END)
		self.e7.delete(0,END)
		self.e9.delete(0,END)
		self.e10.delete(0,END)
		self.e11.delete(0,END)
		self.e16.delete(0,END)
        
		self.inputFilePath = self.InputBMFileName
		self.inputFilePathStringList = self.inputFilePath.split('/')
		self.inputFileNameString = self.inputFilePathStringList[-1]
		self.inputFileNameStringList = self.inputFileNameString.split('_')
        
		self.selectedBMFileType = 'unknown'
		self.selectedPAVendor = 'vendorA'
		self.customerNameGUI = ''
		self.projectNameGUI = ''





		if ('Internal' in self.inputFileNameString):
		    self.selectedBMFileType = 'Internal'
#		    #print('selectedBMFileType: ',self.selectedBMFileType)
		    self.customerNameGUI = self.inputFileNameStringList[0]
#		    #print("customerNameGUI: ",self.customerNameGUI)
		    indexBenchmark = self.inputFileNameStringList[1].index('Benchmark')
		    self.projectNameGUI = self.inputFileNameStringList[1][:indexBenchmark-1]
#		    projectNameGUI = inputFileNameStringList[1][:-10]
#		    #print("projectNameGUI: ",self.projectNameGUI)

		    ki = self.inputFilePath.index('Internal')

		    if ('G2G' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'WWG'
#		        #print('selectedPAVendor: ',self.selectedPAVendor)
		    elif ('AGI' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'AGI'
		    elif ('GMX' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'AIT'
		    elif ('GBE' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'GBE'
		    elif ('FNL' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'FNL'
                
		elif ('PA' in self.inputFileNameString):
		    self.selectedBMFileType = 'External'
#		    #print('selectedBMFileType: ',self.selectedBMFileType)
		    self.customerNameGUI = self.inputFileNameStringList[0]
#		    #print("customerNameGUI: ",self.customerNameGUI)
		    self.projectNameGUI = self.inputFileNameStringList[1]
#		    #print("projectNameGUI: ",self.projectNameGUI)
		    ki = self.inputFilePath.index('PA')

		    if ('WWG' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'WWG'
#		        #print('selectedPAVendor: ',self.selectedPAVendor)
		    elif ('AGI' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'AGI'
		    elif ('GMX' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'GMX'
		    elif ('AIT' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'AIT'
		    elif ('GBE' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'GBE'
		    elif ('FNL' in self.inputFilePath[ki:]):
		        self.selectedPAVendor = 'FNL'
                
#		self.r2.select()

#		self.dfpreview = []


# initial value for self.numberOfLinesGUI & self.totalIncumbentSpendGUI
		self.NBnumberOfLinesGUI=0
		self.NBtotalIncumbentSpendGUI=0
# Set default value for <# of Lines> and <Total Incumbent Spend> on GUI Entry Box
		if self.selectedBMFileType=='External':
			fileDirectoryNum = self.InputBMFileName
			xls = pd.ExcelFile(fileDirectoryNum)
			sheetNameList = xls.sheet_names
			if "Summary" in sheetNameList:
				sheetNameNum = "Summary"
				dfNum= pd.read_excel(fileDirectoryNum,sheet_name=sheetNameNum)

				first_column_header_name = dfNum.columns[0]

                
				dfNum =dfNum.set_index([first_column_header_name])
#				dfpreview = dfNum
#				#print("!!!!!!!!!!!!!!!!!!!!!!ROLLING!!!!!!!!!!!!!!!!!")
#				dfNum.rolling(3,win_type='triang').sum()
				if "SKU's not meeting threshold" in dfNum.index.tolist():
#					#print("&&&&&&&&&&&&&&& In the rows&&&&&&&&&")
					self.NBnumberOfLinesGUI = dfNum.loc["SKU's not meeting threshold"][0]
#					#print("NBnumberOfLinesGUI: ",self.NBnumberOfLinesGUI)
					self.NBtotalIncumbentSpendGUI = dfNum.loc["SKU's not meeting threshold"][1]
#					#print("totalIncumbentSpendGUI: ",self.NBtotalIncumbentSpendGUI)

					self.e9.delete(0,END)                
					self.e9.insert(0,round(float(self.NBtotalIncumbentSpendGUI),2))
					self.e10.delete(0,END)                
					self.e10.insert(0,int(self.NBnumberOfLinesGUI))

				elif "SKUs not meeting threshold" in dfNum.index.tolist():
#					#print("&&&&&&&&&&&&&&& In the rows&&&&&&&&&")
					self.NBnumberOfLinesGUI = dfNum.loc["SKUs not meeting threshold"][0]
#					#print("NBnumberOfLinesGUI: ",self.NBnumberOfLinesGUI)
					self.NBtotalIncumbentSpendGUI = dfNum.loc["SKUs not meeting threshold"][1]
#					#print("totalIncumbentSpendGUI: ",self.NBtotalIncumbentSpendGUI)

					self.e9.delete(0,END)                
					self.e9.insert(0,round(float(self.NBtotalIncumbentSpendGUI),2))
					self.e10.delete(0,END)                
					self.e10.insert(0,self.NBnumberOfLinesGUI)

				else:
					self.e9.delete(0,END) 
					self.e10.delete(0,END)
        
                
# Set default value for SheetName for <Vendor Name> on GUI Dropdown Menu
		if self.selectedPAVendor=='WWG':
			self.c1.set('WWG')
		elif self.selectedPAVendor=='GBE':
			self.c1.set('GBE')
		elif self.selectedPAVendor=='FNL':
			self.c1.set('FNL')           
        
## Set default value for SheetName for <Item Detail> on GUI Dropdown Menu
#		if self.selectedBMFileType=='External':
##			#print("set default sheetname for External")
#			self.c2.set('Item Detail')
#		elif self.selectedBMFileType=='Internal':
##			#print("set default sheetname for Internal")
#			self.c2.set('ItemDetail.Confidential')

# Set default value for SheetName for <Item Detail> on GUI Dropdown Menu
		sheetForItemDetail=''
		x1 = pd.ExcelFile(self.InputBMFileName)
		sheetNameList = x1.sheet_names
		for k in sheetNameList:
			if 'ITEMDETAIL' in k.replace(' ','').upper():
				sheetForItemDetail=k
				if sheetForItemDetail.replace(" ","").upper() == 'ITEMDETAIL' or sheetForItemDetail.replace(" ","").upper() == 'ITEMDETAIL.CONFIDENTIAL':
					break
		self.c2.set(sheetForItemDetail)

# Set default value for Benchmark Type on GUI Dropdown Menu
		if self.selectedBMFileType=='External':
#			#print("set default sheetname for External")
			self.c7.set('External')
		elif self.selectedBMFileType=='Internal':
#			#print("set default sheetname for Internal")
			self.c7.set('Internal')
            
## Set default value for SheetName for <Excluded> on GUI Dropdown Menu
#		if self.selectedBMFileType=='External':
##			#print("set default sheetname for External")
#			self.c3.set('Excluded')
#		elif self.selectedBMFileType=='Internal':
##			#print("set default sheetname for Internal")
#			self.c3.set('Excluded.Confidential')

# Set default value for SheetName for <Excluded> on GUI Dropdown Menu
		sheetForExcluded=''
#		x1 = pd.ExcelFile(self.InputBMFileName)
#		sheetNameList2 = x1.sheet_names
		for k in sheetNameList:
			if 'EXCLUDED' in k.replace(' ','').upper():
				sheetForExcluded=k
				if sheetForExcluded.replace(" ","").upper() == 'EXCLUDED' or sheetForExcluded.replace(" ","").upper() == 'EXCLUDED.CONFIDENTIAL':
					break
		self.c3.set(sheetForExcluded)

		self.outputFileNameDefault="OutputFile_MB"
# Set default value for Output File Name on GUI Entry
		if self.selectedBMFileType=='External':
			self.outputFileNameDefault = self.customerNameGUI + "_" + self.projectNameGUI + "_" + "External " + self.selectedPAVendor + "_MB"
		elif self.selectedBMFileType=='Internal':
			self.outputFileNameDefault = self.customerNameGUI + "_" + self.projectNameGUI + "_" + "Internal " + self.selectedPAVendor.replace("WWG","G2G") + "_MB"

		self.e5.delete(0,END)                
		self.e5.insert(0,self.outputFileNameDefault)    


# Set default value for Customer Name on GUI Entry
		self.e6.delete(0,END)                
		self.e6.insert(0,self.customerNameGUI)

        
# Set default value for Project Name on GUI Entry
		self.e7.delete(0,END)                
		self.e7.insert(0,self.projectNameGUI)

        
# Set default value for Date on GUI Entry
		ttt = os.path.getmtime(self.InputBMFileName)
		self.dateInputGUI=datetime.datetime.fromtimestamp(ttt).isoformat()[:10]
#		#print(self.dateInputGUI)
		self.e12.delete(0,END)                
		self.e12.insert(0,self.dateInputGUI)
        
        
#Call the "duplicateColumnsCheck" function to automated check duplicate columns for the first time       

		self.messageForImportantMissingColumns="Please check"
		self.MBFormatConvertor()
		print("=======================================================================================================")
		print("======================================Preview of New File Below========================================")
		print("=======================================================================================================")
		print(self.df3.head(50))
        
		self.duplicateColumnsCheck()
        
		if sheetForItemDetail.upper().replace(" ","")!="ITEMDETAIL" and sheetForItemDetail.upper()!="ITEMDETAIL.CONFIDENTIAL":
			messagebox.showwarning("Please Double Check Sheet Name for Item Detail","Sheet name for Item Detail is not normal, please double check before exporting")

		sheetForExcluded.upper()!="EXCLUDED"
		sheetForExcluded.upper()!="EXCLUDED.CONFIDENTIAL"
            
		if sheetForExcluded.upper().replace(" ","")!="EXCLUDED" and sheetForExcluded.upper()!="EXCLUDED.CONFIDENTIAL":
			messagebox.showwarning("Please Double Check Sheet Name for Excluded","Sheet name for Excluded is not normal, please double check before exporting")
    
    
#		#print("qqqqqq")
#		#print(dfNum.rolling(3,win_type='triang').sum())
#		dfNum.head(5)
        
#	#print("r2: ",self.rvalue2)
#		#print(self.InputBMFileName)
#		#print(self.radio.get())

#dfpreview.rolling(3,win_type='triang').sum()


	def duplicateColumnsCheck(self):
    # Get file directory from entry box
		self.fileDirectory1 = self.InputBMFileName

    # get sheet name for Item Detail    
		self.sheetName1 = self.c2.get()
    #                #print("entry:",self.sheetName1)

    # get sheet name for Excluded
		self.sheetName2 = self.c3.get()
		#print("entry3: ", self.sheetName2)


		self.rvalue2= self.radio2.get()
    #                #print("r2: ",self.rvalue2)
		self.rvalue3= self.radio3.get()
    #                #print("r3: ",self.rvalue3)


		self.df1= pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName1)

		inputColumnList_original = list(self.df1.loc[0])
		inputColumnList_UPPER_NOSPACE = list(self.df1.loc[0].astype(str).str.replace(' ','').str.upper())
#		#print("input Column list: ",inputColumnList_UPPER_NOSPACE)

		headers = self.df1.columns


#        #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(self.df1.columns.str.replace(' ','').str.upper()))
		columnHeaderIndex=0
		if 'PRODUCTSEGMENT' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'PRODUCTFAMILY' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'SAVINGS%' in list(self.df1.columns.str.replace(' ','').str.upper()):
			#print("################PASS!!!")
			pass
		else:
			for i in range(12):
				columnHeaderIndex=i
				list1 = list(self.df1.loc[i,:].astype(str).str.replace(' ','').str.upper())
				#print("round ", i)
				#print("list1: ",list1)
				if 'PRODUCTSEGMENT' in list1 or 'PRODUCTFAMILY' in list1 or 'SAVINGS%' in list1:
					headers = self.df1.iloc[columnHeaderIndex]
					#print("headers: ",headers)
					columnHeaderIndex = columnHeaderIndex + 1
					break            
				#print("STILL GOING!")

		new_df1= pd.DataFrame(self.df1.values[columnHeaderIndex:],columns=headers)
		#print("##List#$$$###$$$ Headers: ",new_df1.columns.str.replace('.1',''))
		        
		        
		s1 = new_df1.columns.str.replace('.1','').value_counts()>1
		s2 = s1[s1==True]
		duplicateColumnNamesList_ItemDetail = list(s2.index)
		numberOfDuplicates_ItemDetail = len(duplicateColumnNamesList_ItemDetail)
		#print("numberOfDuplicates_ItemDetail: ",numberOfDuplicates_ItemDetail)
		messageForDuplicateColumns = "; ".join(duplicateColumnNamesList_ItemDetail)
        
#====================================================================================================
#Excluded
#		numberOfDuplicates_Excluded=0
#		if (self.selectedPAVendor!='FNL' or self.selectedBMFileType!='Internal'):
		df_excluded = pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName2)

		inputColumnList_original_excluded = list(df_excluded.loc[0])
		inputColumnList_UPPER_NOSPACE_excluded = list(df_excluded.loc[0].astype(str).str.replace(' ','').str.upper())
		#print("input Column list_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)

		headers_excluded = df_excluded.columns    

		#print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(df_excluded.columns.str.replace(' ','').str.upper()))
		columnHeaderIndex_excluded=0
		if 'UNITPRICE' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'QUANTITY' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'SAVINGS%' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'PRODUCTSEGMENT' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'PRODUCTFAMILY' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'NOTES' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'XSORT' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'CUSTOMERNAME' in list(df_excluded.columns.str.replace(' ','').str.upper()):
			#print("################PASS!!!")
			pass
		else:
			for i in range(12):
				columnHeaderIndex=i
				list1 = list(df_excluded.loc[i,:].astype(str).str.replace(' ','').str.replace('.','').str.upper())
				#print("round ", i)
				#print("list1: ",list1)
				if 'UNITPRICE' in list1 or 'SEQNO' in list1 or 'SAVINGS%' in list1 or 'QUANTITY' in list1 or 'PRODUCTSEGMENT' in list1 or 'PRODUCTFAMILY' in list1 or 'NOTES' in list1 or 'XSORT' in list1 or 'CUSTOMERNAME' in list1:
					headers_excluded = df_excluded.iloc[columnHeaderIndex]
					#print("headers_excluded: ",headers_excluded)
					columnHeaderIndex_excluded = columnHeaderIndex_excluded + 1
					break            
				#print("STILL GOING!")    

		new_df_excluded= pd.DataFrame(df_excluded.values[columnHeaderIndex_excluded:],columns=headers_excluded)
		#print("###$$$###$$$ Headers: ",headers)
        
        
		s3 = new_df_excluded.columns.str.replace('.1','').value_counts()>1
		s4 = s3[s3==True]
		duplicateColumnNamesList_Excluded = list(s4.index)
		numberOfDuplicates_Excluded = len(duplicateColumnNamesList_Excluded)
		#print("numberOfDuplicates_Excluded: ",numberOfDuplicates_Excluded)
		messageForDuplicateColumns_Excluded = "; ".join(duplicateColumnNamesList_Excluded)
        
#====================================================================================================        
        
		if numberOfDuplicates_ItemDetail == 0 and numberOfDuplicates_Excluded==0:
			#print("No Duplicates!!!!")
			messagebox.showinfo("No Duplicates","No Duplicates :) \nPlease fill the following information and export the file!")
            
		elif numberOfDuplicates_ItemDetail >0 and numberOfDuplicates_Excluded>0:
			#print("Duplicates_both: ",messageForDuplicateColumns)
			outputMessage = "Duplicate column name(s): \n\n[Item Detail]: " + messageForDuplicateColumns + "\n[Excluded]: "+messageForDuplicateColumns_Excluded+"\n\nPlease modify the column name(s)"
			messagebox.showwarning("Duplicates",outputMessage)
        
		elif numberOfDuplicates_ItemDetail >0 and numberOfDuplicates_Excluded==0:
			#print("Duplicates_both: ",messageForDuplicateColumns)
			outputMessage = "Duplicate column name(s): \n\n[Item Detail]: " + messageForDuplicateColumns + "\n\nPlease modify the column name(s)"
			messagebox.showwarning("Duplicates",outputMessage)

		elif numberOfDuplicates_ItemDetail==0 and numberOfDuplicates_Excluded>0:
			#print("Duplicates_both: ",messageForDuplicateColumns)
			outputMessage = "Duplicate column name(s): \n\n[Excluded]: " + messageForDuplicateColumns_Excluded +"\n\nPlease modify the column name(s)"
			messagebox.showwarning("Duplicates",outputMessage)
            
		messagebox.showwarning("Important Missing Column(s)",self.messageForImportantMissingColumns)
            
#		self.stringForImportantMissingColumns = "; ".join(self.importantMissingColumnList_ItemDetail)
#		self.messageForImportantMissingColumns = "Important missing column(s): \n\n[Item Detail]: " + self.stringForImportantMissingColumns + "\n\nPlease check them before exporting."

        
	def MBFilePath(self):
		self.OutputfileNameMB = fd.askdirectory()
		self.OutputConvertedFileFolderVar.set(self.OutputfileNameMB)
#		#print(self.OutputfileNameMB)
#		#print(self.radio.get())
		

	def MBCombinedInputFolderPath(self): 
		self.InputfolderNameMB = fd.askdirectory()
		self.MBFileLocationVar.set(self.InputfolderNameMB)
#	self.OutputConvertedFileFolderVar.set(self.OutputfolderNameMB)


	def MBCombinedOutputFolderPath(self):
		self.OutputfolderNameMB = fd.askdirectory()
		self.OutputFolderVar.set(self.OutputfolderNameMB)
#	self.OutputConvertedFileFolderVar.set(self.OutputfolderNameMB)


	def MBFileCombiner(self):
        
#		self.rvalue9= self.radio9.get()
#		print("r9: ",self.rvalue9)
        
		folderDirectory = self.e20.get()
		#print(folderDirectory)
		filesNames = os.listdir(folderDirectory)
		df_output=pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Savings $','Savings %','Savings cat.',
                'PA Vendor extended price','PA Vendor unit price','PA Vendor Item Number item #','Code','Status (in/out)',
                'PA Vendor catalog price','Act price','PA Vendor unit of measure','PA Vendor unit/pack','PA Manufacturer name',
                'PA Manufacturer number','PA Vendor Description1','PA Vendor Description2','PA Vendor Product segment1','PA Vendor Product category1',
                'PA Vendor Product family1','CSPL Y/N','Customer name','Project Name','PA Vendor','Location','# Lines','# Transactions','Current Extended',
                'Current Price','Date of Benchmark'])     

#		df_output = df_output.set_index(['Incumbent Distributor name'])
		sheetName1 = "Master Template"

		for i in filesNames:
			currentFileDirectory = folderDirectory +'/'+ i
			#print('currentFileDirectory: ',currentFileDirectory)
			df_current = pd.DataFrame()
			indexForLastDot = i.rfind('.')
			getFileTypeName = i[indexForLastDot+1:]
			if getFileTypeName == 'csv':
				df_current = pd.read_csv(currentFileDirectory,encoding="ISO-8859-1")
			elif 'xl' in getFileTypeName:    
				df_current= pd.read_excel(currentFileDirectory,sheet_name=sheetName1)
#			df_current = df_current.set_index(['Incumbent Distributor name'])
			df_output = pd.DataFrame(pd.concat([df_output,df_current]),columns=list(df_output.columns))
            

#	df_output = df_output.drop(columns=['iintndex'])
#		df_output = df_output.set_index(['Incumbent Distributor name'])


#		self.rvalue9= self.radio9.get()
#		print("r9: ",self.rvalue9)        

		MBCombinedOutputFolderDirectory = self.e21.get()
		MBCombinedOutputFileName = self.e22.get()
        
		MBCombinedOutputFileFullName = MBCombinedOutputFileName + ".xlsx"
        
		outputFolderfilesNames = os.listdir(MBCombinedOutputFolderDirectory)
		print(outputFolderfilesNames)

		if (MBCombinedOutputFileFullName in outputFolderfilesNames):
			print("Same name file!!!!!!!!!")
			whetherOverwrite = messagebox.askyesno("Overwrite?", "The output file name already exists in this folder, do you want to overwrite the previous file? \n \nYes - to overwrite the previous file \nNo - to change the Output file name or Folder")
			if whetherOverwrite == True:
				continueExportFile = True
			elif whetherOverwrite == False:
				pass
        
		else:            
			continueExportFile = True
        
        
        
		if continueExportFile == True:        
        
        
        
        
        
			MBCombinedOutputDirectory = MBCombinedOutputFolderDirectory +"/"+MBCombinedOutputFileName+".xlsx"
            
			writer2= pd.ExcelWriter(MBCombinedOutputDirectory)
			df_output.to_excel(writer2,sheet_name='Master Template',index=False)
			writer2.save()
			theMessage = "The combined master Excel file has been created!"
			messagebox.showinfo("Exported Successfully", theMessage)
			os.startfile(MBCombinedOutputDirectory)
#                #print(self.outputFileDirectory)

		
		
		
		
		
#    def loadInputExcel(self):

	def MBFormatConvertor(self):
		self.PAVendor = self.c1.get()
		self.BMFileType = self.c7.get()
		#print("%%%%%%%%%% BMFileType: ",self.BMFileType)
#		#print('self.BMFileType: ',self.BMFileType)
#		#print(self.PAVendor)
		if self.PAVendor == 'WWG' and self.BMFileType =="Internal":
			#print("$$$$$$$$ Internal $$$$$$$ ")
			self.MBFormatConvertWWGInternal()
		elif self.PAVendor == 'WWG' and self.BMFileType =="External":
			#print("$$$$$$$$ External $$$$$$$ ")
			self.MBFormatConvertWWGExternal()
		
		elif self.PAVendor == "GBE" and self.BMFileType == "External":
			self.GBEExternal()
		
		elif self.PAVendor == "GBE" and self.BMFileType == "Internal":
			self.GBEInternal()
            
		elif self.PAVendor == "FNL" and self.BMFileType == "External":
			self.FNLExternal()
		
		elif self.PAVendor == "FNL" and self.BMFileType == "Internal":
			self.FNLInternal()
		
		
		
		
		
		

	def FNLInternal(self):


#==================================Load Excel=================================================

# Get file directory from entry box
                self.fileDirectory1 = self.InputBMFileName

# get sheet name for Item Detail    
                self.sheetName1 = self.c2.get()
#                #print("entry:",self.sheetName1)

# get sheet name for Excluded
#                self.sheetName2 = self.c3.get()
#                #print("entry3: ", self.sheetName2)

                
                self.rvalue2= self.radio2.get()
#                #print("r2: ",self.rvalue2)
                self.rvalue3= self.radio3.get()
#                #print("r3: ",self.rvalue3)

                
                self.df1= pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName1)

                inputColumnList_original = list(self.df1.loc[0])
                inputColumnList_UPPER_NOSPACE = list(self.df1.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list: ",inputColumnList_UPPER_NOSPACE)

                headers = self.df1.columns
                
                
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(self.df1.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex=0
                if 'PARTNUMBER' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'DESCRIPTION' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'SAVINGS%' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'LPP' in list(self.df1.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(self.df1.loc[i,:].astype(str).str.replace(' ','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if 'PARTNUMBER' in list1 or 'DESCRIPTION' in list1 or 'SAVINGS%' in list1 or 'LPP' in list1:
                            headers = self.df1.iloc[columnHeaderIndex]
                            #print("headers: ",headers)
                            columnHeaderIndex = columnHeaderIndex + 1
                            break            
                        #print("STILL GOING!")

                new_df1= pd.DataFrame(self.df1.values[columnHeaderIndex:],columns=headers)
                new_df1.head()
#               headers = self.df1.iloc[0]

#===========================================================================================

#               new_df1 = pd.DataFrame(self.df1.values[1:],columns=headers)

#===================Define Dictionary and set output headers====================================

# Dictionary for aliases for output column names
                dictionary_FNL = {}
# can put 'Distributor Name' for now:
                dictionary_FNL['Incumbent Distributor name'] = ['']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_FNL['Incumbent Distributor #'] = ['Part Number']
                dictionary_FNL['Incumbent Description'] = ['Description']
                dictionary_FNL['Incumbent Manufacturer name'] = ['']
                dictionary_FNL['Incumbent Manufacturer number'] = ['']
                dictionary_FNL['Incumbent Unit of measure'] = ['']
                dictionary_FNL['Incumbent Units/pack'] = ['Units/pack']
                dictionary_FNL['Incumbent Pack price'] = ['Pack price']
                dictionary_FNL['Incumbent Total packs'] = ['QTY Shipped']
                dictionary_FNL['Incumbent Unit price'] = ['LPP']
                dictionary_FNL['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_FNL['Total incumbent spend'] = ['Extended LPP']
                dictionary_FNL['Savings $'] = ['Savings $']
                dictionary_FNL['Savings %'] = ['Savings %']
                dictionary_FNL['Savings cat.'] = ['Savings cat']
                dictionary_FNL['PA Vendor extended price'] = ['PA Extended','PA Sell Ext']
                dictionary_FNL['PA Vendor unit price'] = ['PA Price','PA Sell Each']
                dictionary_FNL['PA Vendor Item Number item #'] = ['']
                dictionary_FNL['Code'] = ['']
                dictionary_FNL['Status (in/out)'] = ['Status (in/out)']
                dictionary_FNL['PA Vendor catalog price'] = ['catalog price']
                dictionary_FNL['Act price'] = ['Act Price Moderate','Act price']
                dictionary_FNL['PA Vendor unit of measure'] = ['unit of measure','Catalog price UOM']
                dictionary_FNL['PA Vendor unit/pack'] = ['unit/pack']
                dictionary_FNL['PA Manufacturer name'] = ['']
                dictionary_FNL['PA Manufacturer number'] = ['']
                dictionary_FNL['PA Vendor Description1'] = ['Description1']
                dictionary_FNL['PA Vendor Description2'] = ['Description2']
                dictionary_FNL['PA Vendor Product segment1'] = ['Product segment']
                dictionary_FNL['PA Vendor Product category1'] = ['Cat 2','Category']
                dictionary_FNL['PA Vendor Product family1'] = ['Product family']
                dictionary_FNL['CSPL Y/N'] = ['CSPL']
                dictionary_FNL['Customer name'] = ['']
                dictionary_FNL['Project Name'] = ['']
                dictionary_FNL['PA Vendor'] = ['']
                dictionary_FNL['Location'] = ['Location','CUSTOMER NAME']
                dictionary_FNL['# Lines'] = ['# Lines']
                dictionary_FNL['# Transactions'] = ['# Transactions','TRANSACTIONS']
                dictionary_FNL['Current Extended'] = ['Current Extended']
                dictionary_FNL['Current Price'] = ['Current Price']
                dictionary_FNL['Date of Benchmark'] = ['']


                self.df3=pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Savings $','Savings %','Savings cat.',
                'PA Vendor extended price','PA Vendor unit price','PA Vendor Item Number item #','Code','Status (in/out)',
                'PA Vendor catalog price','Act price','PA Vendor unit of measure','PA Vendor unit/pack','PA Manufacturer name',
                'PA Manufacturer number','PA Vendor Description1','PA Vendor Description2','PA Vendor Product segment1','PA Vendor Product category1',
                'PA Vendor Product family1','CSPL Y/N','Customer name','Project Name','PA Vendor','Location','# Lines','# Transactions','Current Extended',
                'Current Price','Date of Benchmark'])

#======================================================================================
            
                inputColumnList_UPPER_NOSPACE = list(headers.astype(str).str.replace(' ','').str.upper())
                
                #print("dictionary_FNL.key: ",dictionary_FNL.keys())
                #print("inputColumnList_UPPER_NOSPACE: ",inputColumnList_UPPER_NOSPACE)

                for m in dictionary_FNL.keys():
                    for n in dictionary_FNL[m]:
                        aindex=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE:
                            aindex = int(inputColumnList_UPPER_NOSPACE.index(n.replace(' ','').upper()))
                            self.df3[m] = new_df1[str(list(headers)[aindex])]
                            
                self.df3['Code']='E'

##################################################################################
#Excluded file
   
    

##################################################################################
                self.df3['# Lines']=1
#                self.df3['# Transactions']=0
#                self.df3['Current Extended']=0
#                self.df3['Current Price']=0

                self.df3 = self.df3.reset_index()
# Standardize the 'Code' ('Description match' to 'DM', 'Exact' to 'E', etc.)
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='SOURCEDITEM')]="S"
# Standardize the 'Code' ('NOT ACTIVE' to 'D' <Discontinued>)
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='NOTACTIVE')]="DISC"
# Standardize the 'Code' (All numbers to 'R' <Return>)
                self.df3['Code'].loc[self.df3['Code']!=0].loc[self.df3.applymap(lambda x: isinstance(x, (int,float)))['Code']==True]='R'
#                self.df3['Code'].loc[self.df3['Code']!=0].loc[self.df3.applymap(lambda x: isinstance(x, (int,float)))['Code']==True]='R'
    
                count_row = self.df3.shape[0]
                #print("count_row: ",count_row)
            
# Append for "Customer Name" Column from user entry

# get user input from "Customer name" in GUI
                self.CustomerNameInput = self.e6.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Customer name'] = self.CustomerNameInput
    
# get user input from "Total incumbent spend" in GUI
#                selfTotalIncumbentSpend = int(self.e6.get())
# assign the values for "Total incumbent spend" column to the input value
#                self.df3['Total incumbent spend'] = selfTotalIncumbentSpend
    

# get user input from "Customer name" in GUI
                self.ProjectNameInput = self.e7.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Project Name'] = self.ProjectNameInput
    
# get user input from "PA Vendor" in GUI
                self.PAVendor = self.c1.get()
                #print("C1: ",self.c1)
# assign the values for "PA Vendor" column to the input value
                self.df3['PA Vendor'] = self.PAVendor

    
# get user input from "PA Vendor" in GUI
                self.PAVendor = self.c1.get()
#                #print("C1: ",self.c1)
# assign the values for "Incumbent Distributor name" column to the input value
                self.df3['Incumbent Distributor name'] = self.PAVendor
    
# get user input from "Location" in GUI
#                self.inputlocation = self.e11.get()
# assign the values for "Location" column to the input value
#                self.df3['Location'] = self.inputlocation
    
# get user input from "Date of Benchmark" in GUI
                self.DateOfBenchmark = self.e12.get()
# assign the values for "Date of Benchmark" column to the input value
                self.df3['Date of Benchmark'] = self.DateOfBenchmark
    
# Stardardize the 'CSPL Y/N'  ('Y' to 'Yes', 'N' to 'No')
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='Y']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='N']="No"
        
        
# Standardize the 'Code' ('Description match' to 'DM', 'Exact' to 'E', etc.)
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='EXACT.')]="E"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='FUNCTION.')]="F"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='DESCRIPTION.')]="DM"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='INCOMPLETE.')]="X"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='DONOTCROSS')]="DNC"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='OUTOFSYSTEM')]="O"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='FINDMRO')]="M"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='NEEDMOREINFO.')]="X"        
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='POTENTIALSOURC.')]="O"
                
#                SpendforNonBenchmark = self.e9.get()
#                self.df3.loc[0,'Non-Benchmarked Spend']=SpendforNonBenchmark        
        
#                numberOfLinesNonBenchmark = self.e10.get()
#                self.df3.loc[0,'Non-Benchmarked Number of lines']=numberOfLinesNonBenchmark
                self.df3 = self.df3.drop(columns=['index'])
    
#                self.df3 = self.df3.set_index(['Incumbent Distributor name'])

#self.df3.rolling(3,win_type='triang').sum()
        
#                self.outputdf = self.df3
        
#                self.dftoExcel()
        
        
        
    
	def FNLExternal(self):
                self.fileDirectory1 = self.InputBMFileName
                
# get sheet name for Item Detail    
                self.sheetName1 = self.c2.get()
#                #print("entry:",self.sheetName1)

# get sheet name for Excluded
                self.sheetName2 = self.c3.get()
                #print("entry3: ", self.sheetName2)

                
                self.rvalue2= self.radio2.get()
#                #print("r2: ",self.rvalue2)
                self.rvalue3= self.radio3.get()
#                #print("r3: ",self.rvalue3)

                
                self.df1= pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName1)

                inputColumnList_original = list(self.df1.loc[0])
                inputColumnList_UPPER_NOSPACE = list(self.df1.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list: ",inputColumnList_UPPER_NOSPACE)

                headers = self.df1.columns
                
                
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(self.df1.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex=0
                if 'SAVINGS$' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'PASELL' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'SAVINGS%' in list(self.df1.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(self.df1.loc[i,:].astype(str).str.replace(' ','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if 'SAVINGS$' in list1 or 'PASELL' in list1 or 'SAVINGS%' in list1:
                            headers = self.df1.iloc[columnHeaderIndex]
                            #print("headers: ",headers)
                            columnHeaderIndex = columnHeaderIndex + 1
                            break            
                        #print("STILL GOING!")


                
#               #print(columnHeaderIndex)
#               #print("Headers: ",headers)
                new_df1= pd.DataFrame(self.df1.values[columnHeaderIndex:],columns=headers)
                new_df1.head()
#               headers = self.df1.iloc[0]

#===========================================================================================

#               new_df1 = pd.DataFrame(self.df1.values[1:],columns=headers)

#===================Define Dictionary and set output headers====================================

# Dictionary for aliases for output column names
                dictionary_FNL = {}
# can put 'Distributor Name' for now:
                dictionary_FNL['Incumbent Distributor name'] = ['Distributor','Vendor']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_FNL['Incumbent Distributor #'] = ['WWG Part #','Supplier Item # (Part No.)','Vendor Part Number']
                dictionary_FNL['Incumbent Description'] = ['Description','Material Description']
                dictionary_FNL['Incumbent Manufacturer name'] = ['BRAND NAME','Manufacturer Name - MFR','Manufacturer Name – MFR']
                dictionary_FNL['Incumbent Manufacturer number'] = ['Part Number']
                dictionary_FNL['Incumbent Unit of measure'] = ['UOM']
                dictionary_FNL['Incumbent Units/pack'] = ['Units/pack']
                dictionary_FNL['Incumbent Pack price'] = ['Pack Price']
                dictionary_FNL['Incumbent Total packs'] = ['Quantity','Total Qty','QTY PURCHASED','Sum of Bill Qty']
                dictionary_FNL['Incumbent Unit price'] = ['Unit price']
                dictionary_FNL['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_FNL['Total incumbent spend'] = ['Ext. Price','Extended Price']
                dictionary_FNL['Savings $'] = ['Savings $']
                dictionary_FNL['Savings %'] = ['Savings %']
                dictionary_FNL['Savings cat.'] = ['Savings cat.']
                dictionary_FNL['PA Vendor extended price'] = ['PA Ext','PA Extended','Lowest Ext']
                dictionary_FNL['PA Vendor unit price'] = ['PA Sell']
                dictionary_FNL['PA Vendor Item Number item #'] = ['FNL P/N','FNL Exact']
                dictionary_FNL['Code'] = ['Match Type','Exact or Sub']
                dictionary_FNL['Status (in/out)'] = ['Status (in/out)']
                dictionary_FNL['PA Vendor catalog price'] = ['catalog price']
                dictionary_FNL['Act price'] = ['Act price']
                dictionary_FNL['PA Vendor unit of measure'] = ['Catalog price UOM']
                dictionary_FNL['PA Vendor unit/pack'] = ['']
                dictionary_FNL['PA Manufacturer name'] = ['']
                dictionary_FNL['PA Manufacturer number'] = ['']
                dictionary_FNL['PA Vendor Description1'] = ['Desc','FNL Description']
                dictionary_FNL['PA Vendor Description2'] = ['']
                dictionary_FNL['PA Vendor Product segment1'] = ['Material Segment']
                dictionary_FNL['PA Vendor Product category1'] = ['Product category']
                dictionary_FNL['PA Vendor Product family1'] = ['Material Family']
                dictionary_FNL['CSPL Y/N'] = ['']
                dictionary_FNL['Customer name'] = ['']
                dictionary_FNL['Project Name'] = ['']
                dictionary_FNL['PA Vendor'] = ['']
                dictionary_FNL['Location'] = ['Location','CUSTOMER NAME']
                dictionary_FNL['# Lines'] = ['# Lines']
                dictionary_FNL['# Transactions'] = ['# Transactions','TRANSACTIONS']
                dictionary_FNL['Current Extended'] = ['Current Extended']
                dictionary_FNL['Current Price'] = ['Current Price']
                dictionary_FNL['Date of Benchmark'] = ['']


                self.df3=pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Savings $','Savings %','Savings cat.',
                'PA Vendor extended price','PA Vendor unit price','PA Vendor Item Number item #','Code','Status (in/out)',
                'PA Vendor catalog price','Act price','PA Vendor unit of measure','PA Vendor unit/pack','PA Manufacturer name',
                'PA Manufacturer number','PA Vendor Description1','PA Vendor Description2','PA Vendor Product segment1','PA Vendor Product category1',
                'PA Vendor Product family1','CSPL Y/N','Customer name','Project Name','PA Vendor','Location','# Lines','# Transactions','Current Extended',
                'Current Price','Date of Benchmark'])
#                self.df3[]=
#                self.df3[]=                
#                self.df3[]=
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                

#                #print("-------------self.df3.head----------------")
#                #print(self.df3.head())
        
#                #print("-------------new_self.df1.head----------------")
#                #print(new_df1.head())
        
#                #print("-------------new_self.df1.columns----------------")
#                #print(new_df1.columns)

#                #print("-------------headers----------------")
#                #print(headers)

#======================================================================================
            
                inputColumnList_UPPER_NOSPACE = list(headers.astype(str).str.replace(' ','').str.upper())
                
                #print("dictionary_FNL.key: ",dictionary_FNL.keys())
                #print("inputColumnList_UPPER_NOSPACE: ",inputColumnList_UPPER_NOSPACE)

                for m in dictionary_FNL.keys():
#                    #print("")
#                    #print("m: ",m)
#                    #print("inputcolumnlist: ",inputColumnList_UPPER_NOSPACE)
                    for n in dictionary_FNL[m]:
#                        #print("n: ",n.replace(' ','').upper())
#                        #print("dictionary_FNL[m]: ",dictionary_FNL[m])
#                        #print("******n.replace(' ','').upper(): ",n.replace(' ','').upper())
#                        #print("******inputColumnList_UPPER_NOSPACE: ",inputColumnList_UPPER_NOSPACE)
#                        #print(n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE)
                        
     #                   if n in inputColumnList and n!="Manufacturer name" and n!="Manufacturer number":
                        aindex=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE:
                            aindex = int(inputColumnList_UPPER_NOSPACE.index(n.replace(' ','').upper()))
#                            #print("aindex: ", aindex)
#                            #print("******list(headers)[aindex]: ",list(headers)[aindex])

#                            #print("-$$---------self.df3.head----------------")
#                            #print("self.df3.head()",self.df3.head())
                            
#                            #print("-$$----------str--------------")
#                            #print("str(list(headers)[aindex])",str(list(headers)[aindex]))
    
                            self.df3[m] = new_df1[str(list(headers)[aindex])]
# Put Description according to Exact/Sub

                self.df3['PA Vendor Description1'].loc[self.df3['Code'].astype(str).str.upper()=='SUB']= new_df1['Sub Desc']
    
                self.df3['PA Vendor Description1'].loc[self.df3['Code'].astype(str).str.upper()=='EXACT']= new_df1['Exact Desc']
#                print("*******",self.df3['PA Vendor Description1'].loc[self.df3['Code'].astype(str).str.upper()=='SUB'])
#                print("======######===========",self.df3['PA Vendor Description1'].loc[self.df3['Code'].astype(str).str.upper()=='Sub'])
#                print("&&&&&&&&&==========",new_df1['Sub Desc'])
#                        else:
#                            self.df3[m] = "to be created"
#                self.df3['Code']='E'

##################################################################################
#Excluded file
                df_excluded = pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName2)
    
                inputColumnList_original_excluded = list(df_excluded.loc[0])
                inputColumnList_UPPER_NOSPACE_excluded = list(df_excluded.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)

                headers_excluded = df_excluded.columns    
    
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(df_excluded.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex_excluded=0
                if 'UNITPRICE' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'SEQNO' in list(df_excluded.columns.str.replace(' ','').str.replace('.','').str.upper()) or 'SEQ' in list(df_excluded.columns.str.replace(' ','').str.replace('.','').str.upper()) or 'QUANTITY' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'QTY' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'EXTENDEDPRICE' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'EXT.PRICE' in list(df_excluded.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(df_excluded.loc[i,:].astype(str).str.replace(' ','').str.replace('.','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if ('UNITPRICE' in list1) or ('SEQNO' in list1) or ('SEQ' in list1) or ('QUANTITY' in list1) or ('QTY' in list1) or ('EXTPRICE' in list1) or ('EXTENDEDPRICE' in list1):
                            #print("************BINGO****************")
                            headers_excluded = df_excluded.iloc[columnHeaderIndex]
                            #print("headers_excluded: ",headers_excluded)
                            columnHeaderIndex_excluded = columnHeaderIndex_excluded + 1
                            break           
                        #print("STILL GOING!")    
    
                new_df_excluded= pd.DataFrame(df_excluded.values[columnHeaderIndex_excluded:],columns=headers_excluded)
                new_df_excluded.head()    
    
    
                dictionary_FNL_excluded = {}
# can put 'Distributor Name' for now:
                dictionary_FNL_excluded['Incumbent Distributor name'] = ['Vendor']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_FNL_excluded['Incumbent Distributor #'] = ['Vendor Part Number']
                dictionary_FNL_excluded['Incumbent Description'] = ['Description','Material Description']
                dictionary_FNL_excluded['Incumbent Manufacturer name'] = ['Brand Name']
                dictionary_FNL_excluded['Incumbent Manufacturer number'] = ['Part Number']
                dictionary_FNL_excluded['Incumbent Unit of measure'] = ['UOM']
                dictionary_FNL_excluded['Incumbent Units/pack'] = ['Units/pack']
                dictionary_FNL_excluded['Incumbent Pack price'] = ['Pack price']
                dictionary_FNL_excluded['Incumbent Total packs'] = ['Quantity','Qty']
                dictionary_FNL_excluded['Incumbent Unit price'] = ['Unit Price']
                dictionary_FNL_excluded['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_FNL_excluded['Total incumbent spend'] = ['Extended Price','Ext. Price']
                dictionary_FNL_excluded['Code'] = ['Notes','Code']
    
                df_excluded_tocombine = pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Code'])    
    
                inputColumnList_UPPER_NOSPACE_excluded = list(headers_excluded.astype(str).str.replace(' ','').str.upper())
        
                #print("dictionary_FNL.key_excluded: ",dictionary_FNL_excluded.keys()) 
                #print("inputColumnList_UPPER_NOSPACE_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
    
                for m in dictionary_FNL_excluded.keys():
                    #print("")
                    #print("m: ",m)
                    #print("inputcolumnlist_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
                    for n in dictionary_FNL_excluded[m]:
                        #print("n: ",n.replace(' ','').upper())
                        #print("dictionary_FNL[m]: ",dictionary_FNL_excluded[m])
                        #print("******n.replace(' ','').upper(): ",n.replace(' ','').upper())
                        #print("******inputColumnList_UPPER_NOSPACE_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
                        #print(n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE_excluded)
                        
     #                   if n in inputColumnList and n!="Manufacturer name" and n!="Manufacturer number":
                        aindex_excluded=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE_excluded:
                            aindex_excluded = int(inputColumnList_UPPER_NOSPACE_excluded.index(n.replace(' ','').upper()))
                            #print("aindex_excluded: ", aindex_excluded)
                            #print("******list(headers_excluded)[aindex_excluded]: ",list(headers_excluded)[aindex_excluded])

                            #print("-$$---------df_excluded.head----------------")
                            #print("df_excluded.head()",df_excluded.head())
                            
                            #print("-$$----------str--------------")
                            #print("str(list(headers_excluded)[aindex_excluded])",str(list(headers_excluded)[aindex_excluded]))
    
                            df_excluded_tocombine[m] = new_df_excluded[str(list(headers_excluded)[aindex_excluded])]    
    
                self.df3 = pd.DataFrame(pd.concat([self.df3,df_excluded_tocombine]),columns=list(self.df3.columns))         
##################################################################################
                self.df3['# Lines']=1
                self.df3['# Transactions']=0
                self.df3['Current Extended']=0
                self.df3['Current Price']=0

                self.df3 = self.df3.reset_index()
                
#                position1 = new_self.df1.columns.get_loc('Description') + 1
#                position2 = new_self.df1.columns.get_loc('Description') + 2

#                self.df3['Incumbent Manufacturer name'] = new_self.df1[list(new_self.df1.columns)[position1]]
#                self.df3['Incumbent Manufacturer number'] = new_self.df1[list(new_self.df1.columns)[position2]]

#                position3 = new_self.df1.columns.get_loc('Act Price Moderate') + 1
#                position4 = new_self.df1.columns.get_loc('Act Price Moderate') + 2

#                self.df3 = self.df3.set_index(['Incumbent Distributor name'])
# Append to the last row for Non-Benchmarked Spend and Number of Lines
                count_row = self.df3.shape[0]
                #print("count_row: ",count_row)
                self.df3.loc[count_row,'Total incumbent spend'] = self.e9.get()
                self.df3.loc[count_row,'# Lines'] = self.e10.get()
            
#                self.df3.loc[count_row,'CSPL Y/N'] = 'No'
                self.df3.loc[count_row,'Code'] = 'NB'


            
# Append for "Customer Name" Column from user entry

# get user input from "Customer name" in GUI
                self.CustomerNameInput = self.e6.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Customer name'] = self.CustomerNameInput
    
# get user input from "Total incumbent spend" in GUI
#                selfTotalIncumbentSpend = int(self.e6.get())
# assign the values for "Total incumbent spend" column to the input value
#                self.df3['Total incumbent spend'] = selfTotalIncumbentSpend
    

# get user input from "Customer name" in GUI
                self.ProjectNameInput = self.e7.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Project Name'] = self.ProjectNameInput
    
# get user input from "PA Vendor" in GUI
                self.PAVendor = self.c1.get()
                #print("C1: ",self.c1)
# assign the values for "PA Vendor" column to the input value
                self.df3['PA Vendor'] = self.PAVendor
    
# get user input from "Location" in GUI
                self.inputlocation = self.e11.get()
# assign the values for "Location" column to the input value
#                self.df3['Location'] = self.inputlocation
                self.df3['Location'].loc[self.df3['Location'].astype(str).str.upper()=='NAN']=self.inputlocation
    
# get user input from "Date of Benchmark" in GUI
                self.DateOfBenchmark = self.e12.get()
# assign the values for "Date of Benchmark" column to the input value
                self.df3['Date of Benchmark'] = self.DateOfBenchmark
    
## If needed, can choose to Switch "Manufacture Name" with "Distributor Name"   AND/OR    Switch "Manufacture Number" with "Distributor Number"
#                if self.rvalue2==1:
#
 #                   series3 = self.df3['Incumbent Manufacturer name']
  #                  frame5 = {'Incumbent Distributor name':series3}
   #                 df8 = pd.DataFrame(frame5)
#   #                 df10 = df8.copy()
     #               
      #              df7=self.df3['Incumbent Distributor name'].copy()
       #             self.df3['Incumbent Distributor name']=df8
#       #             self.df3['Incumbent Distributor name']=df10
         #           self.df3['Incumbent Manufacturer name']=df7
          #      
           #     if self.rvalue3==1:
#
 #                   series4 = self.df3['Incumbent Manufacturer number']
  #                  frame6 = {'Incumbent Distributor name':series4}
   #                 df9 = pd.DataFrame(frame6)
#   #                 df12 = df9.copy()
     #               
      #              df11 = self.df3['Incumbent Distributor #'].copy()
       #         self.df3['Incumbent Distributor #']=df9
#       #             self.df3['Incumbent Distributor #']=df12
         #       self.df3['Incumbent Manufacturer number'] =df11

# Add last row for Incumbent Distributor name and Incumbent Manufacturer Name

                self.df3.loc[count_row,'Incumbent Distributor name'] = self.df3.loc[count_row-1,'Incumbent Distributor name']
                self.df3.loc[count_row,'Incumbent Manufacturer name'] = self.df3.loc[count_row-1,'Incumbent Manufacturer name']
    
# Stardardize the 'CSPL Y/N'  ('Y','1','True' to 'Yes', 'N','0',"False","" to 'No',)
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='Y']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='N']="No"
        

# Put Description according to Exact/Sub

#                self.df3['PA Vendor Description1'].loc[self.df3['Code'].astype(str).str.upper()=='Sub']= new_df1['Sub Desc']
        
        
# Standardize the 'Code' ('Description match' to 'DM', 'Exact' to 'E', etc.)
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='EXAC.')]="E"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='FUNCTION.')]="F"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='SUB')]="F"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='DESCRIPTION.')]="DM"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='INCOMPLETE.')]="X"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='DONOTCROSS')]="DNC"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='OUTOFSYSTEM')]="O"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='FINDMRO')]="M"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='NEEDMOREINFO.')]="X"        
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='POTENTIALSOURC.')]="O"
                
#                SpendforNonBenchmark = self.e9.get()
#                self.df3.loc[0,'Non-Benchmarked Spend']=SpendforNonBenchmark        
        
#                numberOfLinesNonBenchmark = self.e10.get()
#                self.df3.loc[0,'Non-Benchmarked Number of lines']=numberOfLinesNonBenchmark

                self.df3 = self.df3.drop(columns=['index'])
    
    
#                self.df3 = self.df3.set_index(['Incumbent Distributor name'])
                
#                self.outputdf = self.df3
#                self.dftoExcel()    
        
        
        
	def GBEInternal(self):


#==================================Load Excel=================================================

# Get file directory from entry box
                self.fileDirectory1 = self.InputBMFileName

# get sheet name for Item Detail    
                self.sheetName1 = self.c2.get()
#                #print("entry:",self.sheetName1)

# get sheet name for Excluded
                self.sheetName2 = self.c3.get()
                #print("entry3: ", self.sheetName2)

                
                self.rvalue2= self.radio2.get()
#                #print("r2: ",self.rvalue2)
                self.rvalue3= self.radio3.get()
#                #print("r3: ",self.rvalue3)

                
                self.df1= pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName1)

                inputColumnList_original = list(self.df1.loc[0])
                inputColumnList_UPPER_NOSPACE = list(self.df1.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list: ",inputColumnList_UPPER_NOSPACE)

                headers = self.df1.columns
                
                
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(self.df1.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex=0
                if 'PRODUCTSEGMENT' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'PRODUCTFAMILY' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'SAVINGS%' in list(self.df1.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(self.df1.loc[i,:].astype(str).str.replace(' ','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if 'PRODUCTSEGMENT' in list1 or 'PRODUCTFAMILY' in list1 or 'SAVINGS%' in list1:
                            headers = self.df1.iloc[columnHeaderIndex]
                            #print("headers: ",headers)
                            columnHeaderIndex = columnHeaderIndex + 1
                            break            
                        #print("STILL GOING!")

                new_df1= pd.DataFrame(self.df1.values[columnHeaderIndex:],columns=headers)
                new_df1.head()
#               headers = self.df1.iloc[0]

#===========================================================================================

#               new_df1 = pd.DataFrame(self.df1.values[1:],columns=headers)

#===================Define Dictionary and set output headers====================================

# Dictionary for aliases for output column names
                dictionary_GBE = {}
# can put 'Distributor Name' for now:
                dictionary_GBE['Incumbent Distributor name'] = ['']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_GBE['Incumbent Distributor #'] = ['']
                dictionary_GBE['Incumbent Description'] = ['ITEM DESCRIPTION']
                dictionary_GBE['Incumbent Manufacturer name'] = ['BRAND NAME']
                dictionary_GBE['Incumbent Manufacturer number'] = ['Manufacturer number','Catalog Number']
                dictionary_GBE['Incumbent Unit of measure'] = ['Unit of measure','UOM']
                dictionary_GBE['Incumbent Units/pack'] = ['Units/pack']
                dictionary_GBE['Incumbent Pack price'] = ['Pack price']
                dictionary_GBE['Incumbent Total packs'] = ['QTY PURCHASED']
                dictionary_GBE['Incumbent Unit price'] = ['Unit price']
                dictionary_GBE['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_GBE['Total incumbent spend'] = ['PURCHASE AMOUNT']
                dictionary_GBE['Savings $'] = ['Savings $']
                dictionary_GBE['Savings %'] = ['Savings %']
                dictionary_GBE['Savings cat.'] = ['Savings cat.']
                dictionary_GBE['PA Vendor extended price'] = ['PA EXTENDED']
                dictionary_GBE['PA Vendor unit price'] = ['GBE Unit Price Moderate','GBE Unit Price','PA Price']
                dictionary_GBE['PA Vendor Item Number item #'] = ['Graybar item #']
                dictionary_GBE['Code'] = ['Code','Cross Reference Code','Notes']
                dictionary_GBE['Status (in/out)'] = ['Status (in/out)']
                dictionary_GBE['PA Vendor catalog price'] = ['catalog price']
                dictionary_GBE['Act price'] = ['Act Price Moderate','Act price','PA COST']
                dictionary_GBE['PA Vendor unit of measure'] = ['GBE unit of measure','Catalog price UOM']
                dictionary_GBE['PA Vendor unit/pack'] = ['GBE unit/pack']
                dictionary_GBE['PA Manufacturer name'] = ['GBE Manufacturer name','GBE Mfg Name','BRAND NAME']
                dictionary_GBE['PA Manufacturer number'] = ['GBE Manufacturer number','GBE Mfg Number']
                dictionary_GBE['PA Vendor Description1'] = ['Description1','GBE Product Description']
                dictionary_GBE['PA Vendor Description2'] = ['Description2']
                dictionary_GBE['PA Vendor Product segment1'] = ['Product segment']
                dictionary_GBE['PA Vendor Product category1'] = ['Product category','MATERIAL CATEGORY']
                dictionary_GBE['PA Vendor Product family1'] = ['Product family']
                dictionary_GBE['CSPL Y/N'] = ['CSP Moderate','CSP','CSP Identification','CSPL']
                dictionary_GBE['Customer name'] = ['']
                dictionary_GBE['Project Name'] = ['']
                dictionary_GBE['PA Vendor'] = ['']
                dictionary_GBE['Location'] = ['Location','CUSTOMER NAME']
                dictionary_GBE['# Lines'] = ['# Lines']
                dictionary_GBE['# Transactions'] = ['# Transactions','TRANSACTIONS']
                dictionary_GBE['Current Extended'] = ['Current Extended']
                dictionary_GBE['Current Price'] = ['Current Price']
                dictionary_GBE['Date of Benchmark'] = ['']


                self.df3=pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Savings $','Savings %','Savings cat.',
                'PA Vendor extended price','PA Vendor unit price','PA Vendor Item Number item #','Code','Status (in/out)',
                'PA Vendor catalog price','Act price','PA Vendor unit of measure','PA Vendor unit/pack','PA Manufacturer name',
                'PA Manufacturer number','PA Vendor Description1','PA Vendor Description2','PA Vendor Product segment1','PA Vendor Product category1',
                'PA Vendor Product family1','CSPL Y/N','Customer name','Project Name','PA Vendor','Location','# Lines','# Transactions','Current Extended',
                'Current Price','Date of Benchmark'])

#======================================================================================
            
                inputColumnList_UPPER_NOSPACE = list(headers.astype(str).str.replace(' ','').str.upper())
                
                #print("dictionary_GBE.key: ",dictionary_GBE.keys())
                #print("inputColumnList_UPPER_NOSPACE: ",inputColumnList_UPPER_NOSPACE)

                for m in dictionary_GBE.keys():
                    for n in dictionary_GBE[m]:
                        aindex=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE:
                            aindex = int(inputColumnList_UPPER_NOSPACE.index(n.replace(' ','').upper()))
                            self.df3[m] = new_df1[str(list(headers)[aindex])]
                            
                self.df3['Code']='E'

##################################################################################
#Excluded file
                df_excluded = pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName2)
    
                inputColumnList_original_excluded = list(df_excluded.loc[0])
                inputColumnList_UPPER_NOSPACE_excluded = list(df_excluded.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)

                headers_excluded = df_excluded.columns    
    
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(df_excluded.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex_excluded=0
                if 'PRODUCTSEGMENT' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'PRODUCTFAMILY' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'NOTES' in list(df_excluded.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(df_excluded.loc[i,:].astype(str).str.replace(' ','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if 'PRODUCTSEGMENT' in list1 or 'PRODUCTFAMILY' in list1 or 'NOTES' in list1:
                            headers_excluded = df_excluded.iloc[columnHeaderIndex]
                            #print("headers_excluded: ",headers_excluded)
                            columnHeaderIndex_excluded = columnHeaderIndex_excluded + 1
                            break            
                        #print("STILL GOING!")    
    
                new_df_excluded= pd.DataFrame(df_excluded.values[columnHeaderIndex_excluded:],columns=headers_excluded)
                new_df_excluded.head()    
    
    
                dictionary_GBE_excluded = {}
# can put 'Distributor Name' for now:
                dictionary_GBE_excluded['Incumbent Distributor name'] = ['Distributor Name']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_GBE_excluded['Incumbent Distributor #'] = ['ITEM NUMBER']
                dictionary_GBE_excluded['Incumbent Description'] = ['ITEM DISCRIPTION']
                dictionary_GBE_excluded['Incumbent Manufacturer name'] = ['BRAND NAME']
                dictionary_GBE_excluded['Incumbent Manufacturer number'] = ['Manufacturer number','Mfg/Vendor Part Number','Catalog Number']
                dictionary_GBE_excluded['Incumbent Unit of measure'] = ['Unit of measure']
                dictionary_GBE_excluded['Incumbent Units/pack'] = ['Units/pack']
                dictionary_GBE_excluded['Incumbent Pack price'] = ['Pack price']
                dictionary_GBE_excluded['Incumbent Total packs'] = ['QTY PURCHASED']
                dictionary_GBE_excluded['Incumbent Unit price'] = ['Unit price']
                dictionary_GBE_excluded['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_GBE_excluded['Total incumbent spend'] = ['PURCHASE AMOUNT']
                dictionary_GBE_excluded['Code'] = ['Notes']
    
                df_excluded_tocombine = pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Code'])    
    
                inputColumnList_UPPER_NOSPACE_excluded = list(headers_excluded.astype(str).str.replace(' ','').str.upper())
        
                #print("dictionary_GBE.key_excluded: ",dictionary_GBE_excluded.keys()) 
                #print("inputColumnList_UPPER_NOSPACE_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
    
                for m in dictionary_GBE_excluded.keys():
                    for n in dictionary_GBE_excluded[m]:
                        
     #                   if n in inputColumnList and n!="Manufacturer name" and n!="Manufacturer number":
                        aindex_excluded=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE_excluded:
                            aindex_excluded = int(inputColumnList_UPPER_NOSPACE_excluded.index(n.replace(' ','').upper()))
                            #print("aindex_excluded: ", aindex_excluded)
                            #print("******list(headers_excluded)[aindex_excluded]: ",list(headers_excluded)[aindex_excluded])

                            #print("-$$---------df_excluded.head----------------")
                            #print("df_excluded.head()",df_excluded.head())
                            
                            #print("-$$----------str--------------")
                            #print("str(list(headers_excluded)[aindex_excluded])",str(list(headers_excluded)[aindex_excluded]))
    
                            df_excluded_tocombine[m] = new_df_excluded[str(list(headers_excluded)[aindex_excluded])]    
    
                self.df3 = pd.DataFrame(pd.concat([self.df3,df_excluded_tocombine]),columns=list(self.df3.columns))    
    

##################################################################################
                self.df3['# Lines']=1
#                self.df3['# Transactions']=0
#                self.df3['Current Extended']=0
#                self.df3['Current Price']=0

                self.df3 = self.df3.reset_index()
# Standardize the 'Code' ('Description match' to 'DM', 'Exact' to 'E', etc.)
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='SOURCEDITEM')]="S"
# Standardize the 'Code' ('NOT ACTIVE' to 'D' <Discontinued>)
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='NOTACTIVE')]="DISC"
# Standardize the 'Code' (All numbers to 'R' <Return>)
                self.df3['Code'].loc[self.df3['Code']!=0].loc[self.df3.applymap(lambda x: isinstance(x, (int,float)))['Code']==True]='R' 
    
                count_row = self.df3.shape[0]
                #print("count_row: ",count_row)
            
# Append for "Customer Name" Column from user entry

# get user input from "Customer name" in GUI
                self.CustomerNameInput = self.e6.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Customer name'] = self.CustomerNameInput
    
# get user input from "Total incumbent spend" in GUI
#                selfTotalIncumbentSpend = int(self.e6.get())
# assign the values for "Total incumbent spend" column to the input value
#                self.df3['Total incumbent spend'] = selfTotalIncumbentSpend
    

# get user input from "Customer name" in GUI
                self.ProjectNameInput = self.e7.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Project Name'] = self.ProjectNameInput
    
# get user input from "PA Vendor" in GUI
                self.PAVendor = self.c1.get()
                #print("C1: ",self.c1)
# assign the values for "PA Vendor" column to the input value
                self.df3['PA Vendor'] = self.PAVendor

    
# get user input from "PA Vendor" in GUI
                self.PAVendor = self.c1.get()
#                #print("C1: ",self.c1)
# assign the values for "Incumbent Distributor name" column to the input value
                self.df3['Incumbent Distributor name'] = self.PAVendor
    
# get user input from "Location" in GUI
#                self.inputlocation = self.e11.get()
# assign the values for "Location" column to the input value
#                self.df3['Location'] = self.inputlocation
    
# get user input from "Date of Benchmark" in GUI
                self.DateOfBenchmark = self.e12.get()
# assign the values for "Date of Benchmark" column to the input value
                self.df3['Date of Benchmark'] = self.DateOfBenchmark
    
# Stardardize the 'CSPL Y/N'  ('Y' to 'Yes', 'N' to 'No')
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='Y']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='N']="No"
        
        
# Standardize the 'Code' ('Description match' to 'DM', 'Exact' to 'E', etc.)
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='EXACT.')]="E"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='FUNCTION.')]="F"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='DESCRIPTION.')]="DM"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='INCOMPLETE.')]="X"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='DONOTCROSS')]="DNC"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='OUTOFSYSTEM')]="O"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='FINDMRO')]="M"
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='NEEDMOREINFO.')]="X"        
                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='POTENTIALSOURC.')]="O"
                
#                SpendforNonBenchmark = self.e9.get()
#                self.df3.loc[0,'Non-Benchmarked Spend']=SpendforNonBenchmark        
        
#                numberOfLinesNonBenchmark = self.e10.get()
#                self.df3.loc[0,'Non-Benchmarked Number of lines']=numberOfLinesNonBenchmark

                self.df3 = self.df3.drop(columns=['index'])
    
#                self.df3 = self.df3.set_index(['Incumbent Distributor name'])

#self.df3.rolling(3,win_type='triang').sum()
        
#                self.outputdf = self.df3
#                self.dftoExcel()
        
        
        
	def GBEExternal(self):
                self.fileDirectory1 = self.InputBMFileName
                
# get sheet name for Item Detail    
                self.sheetName1 = self.c2.get()
#                #print("entry:",self.sheetName1)

# get sheet name for Excluded
                self.sheetName2 = self.c3.get()
                #print("entry3: ", self.sheetName2)

                
                self.rvalue2= self.radio2.get()
#                #print("r2: ",self.rvalue2)
                self.rvalue3= self.radio3.get()
#                #print("r3: ",self.rvalue3)

                
                self.df1= pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName1)

                inputColumnList_original = list(self.df1.loc[0])
                inputColumnList_UPPER_NOSPACE = list(self.df1.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list: ",inputColumnList_UPPER_NOSPACE)

                headers = self.df1.columns
                
                
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(self.df1.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex=0
                if 'PRODUCTSEGMENT' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'PRODUCTFAMILY' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'SAVINGS%' in list(self.df1.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(self.df1.loc[i,:].astype(str).str.replace(' ','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if 'PRODUCT SEGMENT' in list1 or 'PRODUCTFAMILY' in list1 or 'SAVINGS%' in list1:
                            headers = self.df1.iloc[columnHeaderIndex]
                            #print("headers: ",headers)
                            columnHeaderIndex = columnHeaderIndex + 1
                            break            
                        #print("STILL GOING!")


                
#               #print(columnHeaderIndex)
#               #print("Headers: ",headers)
                new_df1= pd.DataFrame(self.df1.values[columnHeaderIndex:],columns=headers)
                new_df1.head()
#               headers = self.df1.iloc[0]

#===========================================================================================

#               new_df1 = pd.DataFrame(self.df1.values[1:],columns=headers)

#===================Define Dictionary and set output headers====================================

# Dictionary for aliases for output column names
                dictionary_GBE = {}
# can put 'Distributor Name' for now:
                dictionary_GBE['Incumbent Distributor name'] = ['Distributor','Vendor']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_GBE['Incumbent Distributor #'] = ['MSC Item Number']
                dictionary_GBE['Incumbent Description'] = ['Description','MRI Description','Item Description']
                dictionary_GBE['Incumbent Manufacturer name'] = ['BRAND NAME','Manufacturer Name - MFR','Manufacturer Name – MFR']
                dictionary_GBE['Incumbent Manufacturer number'] = ['Manufacturer Part Number']
                dictionary_GBE['Incumbent Unit of measure'] = ['UOM']
                dictionary_GBE['Incumbent Units/pack'] = ['Units/pack']
                dictionary_GBE['Incumbent Pack price'] = ['Pack Price']
                dictionary_GBE['Incumbent Total packs'] = ['Quantity','QTY PURCHASED']
                dictionary_GBE['Incumbent Unit price'] = ['Unit price']
                dictionary_GBE['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_GBE['Total incumbent spend'] = ['Extended Provided']
                dictionary_GBE['Savings $'] = ['Savings $']
                dictionary_GBE['Savings %'] = ['Savings %']
                dictionary_GBE['Savings cat.'] = ['Savings cat.']
                dictionary_GBE['PA Vendor extended price'] = ['Graybar extended price','PA Extended']
                dictionary_GBE['PA Vendor unit price'] = ['Graybar Unit Price','PA Price']
                dictionary_GBE['PA Vendor Item Number item #'] = ['Graybar item #']
                dictionary_GBE['Code'] = ['Match Type']
                dictionary_GBE['Status (in/out)'] = ['Status (in/out)']
                dictionary_GBE['PA Vendor catalog price'] = ['catalog price']
                dictionary_GBE['Act price'] = ['Act price']
                dictionary_GBE['PA Vendor unit of measure'] = ['Graybar unit of measure','Catalog price UOM']
                dictionary_GBE['PA Vendor unit/pack'] = ['Graybar unit/pack']
                dictionary_GBE['PA Manufacturer name'] = ['Manufacturer name']
                dictionary_GBE['PA Manufacturer number'] = ['Manufacturer number']
                dictionary_GBE['PA Vendor Description1'] = ['Description1']
                dictionary_GBE['PA Vendor Description2'] = ['']
                dictionary_GBE['PA Vendor Product segment1'] = ['Product segment']
                dictionary_GBE['PA Vendor Product category1'] = ['Product category']
                dictionary_GBE['PA Vendor Product family1'] = ['Product family']
                dictionary_GBE['CSPL Y/N'] = ['']
                dictionary_GBE['Customer name'] = ['']
                dictionary_GBE['Project Name'] = ['']
                dictionary_GBE['PA Vendor'] = ['']
                dictionary_GBE['Location'] = ['Location','CUSTOMER NAME']
                dictionary_GBE['# Lines'] = ['# Lines']
                dictionary_GBE['# Transactions'] = ['# Transactions','TRANSACTIONS']
                dictionary_GBE['Current Extended'] = ['Current Extended']
                dictionary_GBE['Current Price'] = ['Current Price']
                dictionary_GBE['Date of Benchmark'] = ['']


                self.df3=pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Savings $','Savings %','Savings cat.',
                'PA Vendor extended price','PA Vendor unit price','PA Vendor Item Number item #','Code','Status (in/out)',
                'PA Vendor catalog price','Act price','PA Vendor unit of measure','PA Vendor unit/pack','PA Manufacturer name',
                'PA Manufacturer number','PA Vendor Description1','PA Vendor Description2','PA Vendor Product segment1','PA Vendor Product category1',
                'PA Vendor Product family1','CSPL Y/N','Customer name','Project Name','PA Vendor','Location','# Lines','# Transactions','Current Extended',
                'Current Price','Date of Benchmark'])
#                self.df3[]=
#                self.df3[]=                
#                self.df3[]=
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                

#                #print("-------------self.df3.head----------------")
#                #print(self.df3.head())
        
#                #print("-------------new_self.df1.head----------------")
#                #print(new_df1.head())
        
#                #print("-------------new_self.df1.columns----------------")
#                #print(new_df1.columns)

#                #print("-------------headers----------------")
#                #print(headers)

#======================================================================================
            
                inputColumnList_UPPER_NOSPACE = list(headers.astype(str).str.replace(' ','').str.upper())
                
                #print("dictionary_GBE.key: ",dictionary_GBE.keys())
                #print("inputColumnList_UPPER_NOSPACE: ",inputColumnList_UPPER_NOSPACE)

                for m in dictionary_GBE.keys():
#                    #print("")
#                    #print("m: ",m)
#                    #print("inputcolumnlist: ",inputColumnList_UPPER_NOSPACE)
                    for n in dictionary_GBE[m]:
#                        #print("n: ",n.replace(' ','').upper())
#                        #print("dictionary_GBE[m]: ",dictionary_GBE[m])
#                        #print("******n.replace(' ','').upper(): ",n.replace(' ','').upper())
#                        #print("******inputColumnList_UPPER_NOSPACE: ",inputColumnList_UPPER_NOSPACE)
#                        #print(n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE)
                        
     #                   if n in inputColumnList and n!="Manufacturer name" and n!="Manufacturer number":
                        aindex=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE:
                            aindex = int(inputColumnList_UPPER_NOSPACE.index(n.replace(' ','').upper()))
#                            #print("aindex: ", aindex)
#                            #print("******list(headers)[aindex]: ",list(headers)[aindex])

#                            #print("-$$---------self.df3.head----------------")
#                            #print("self.df3.head()",self.df3.head())
                            
#                            #print("-$$----------str--------------")
#                            #print("str(list(headers)[aindex])",str(list(headers)[aindex]))
    
                            self.df3[m] = new_df1[str(list(headers)[aindex])]
#                        else:
#                            self.df3[m] = "to be created"
#                self.df3['Code']='E'

##################################################################################
#Excluded file
                df_excluded = pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName2)
    
                inputColumnList_original_excluded = list(df_excluded.loc[0])
                inputColumnList_UPPER_NOSPACE_excluded = list(df_excluded.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)

                headers_excluded = df_excluded.columns    
    
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(df_excluded.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex_excluded=0
                if 'PRODUCTSEGMENT' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'PRODUCTFAMILY' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'NOTES' in list(df_excluded.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(df_excluded.loc[i,:].astype(str).str.replace(' ','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if 'PRODUCTSEGMENT' in list1 or 'PRODUCTFAMILY' in list1 or 'NOTES' in list1:
                            headers_excluded = df_excluded.iloc[columnHeaderIndex]
                            #print("headers_excluded: ",headers_excluded)
                            columnHeaderIndex_excluded = columnHeaderIndex_excluded + 1
                            break            
                        #print("STILL GOING!")    
    
                new_df_excluded= pd.DataFrame(df_excluded.values[columnHeaderIndex_excluded:],columns=headers_excluded)
#                new_df_excluded.head()    
    
    
                dictionary_GBE_excluded = {}
# can put 'Distributor Name' for now:
                dictionary_GBE_excluded['Incumbent Distributor name'] = ['Distributor']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_GBE_excluded['Incumbent Distributor #'] = ['MSC Item Number']
                dictionary_GBE_excluded['Incumbent Description'] = ['Description','Item Description']
                dictionary_GBE_excluded['Incumbent Manufacturer name'] = ['']
                dictionary_GBE_excluded['Incumbent Manufacturer number'] = ['Manufacturer Part Number']
                dictionary_GBE_excluded['Incumbent Unit of measure'] = ['Unit of Measure (UoM)']
                dictionary_GBE_excluded['Incumbent Units/pack'] = ['Units/pack']
                dictionary_GBE_excluded['Incumbent Pack price'] = ['Pack price']
                dictionary_GBE_excluded['Incumbent Total packs'] = ['Quantity','Qty']
                dictionary_GBE_excluded['Incumbent Unit price'] = ['Unit Price']
                dictionary_GBE_excluded['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_GBE_excluded['Total incumbent spend'] = ['Total Spend']
                dictionary_GBE_excluded['Code'] = ['Notes']
    
                df_excluded_tocombine = pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Code'])    
    
                inputColumnList_UPPER_NOSPACE_excluded = list(headers_excluded.astype(str).str.replace(' ','').str.upper())
        
                #print("dictionary_GBE.key_excluded: ",dictionary_GBE_excluded.keys()) 
                #print("inputColumnList_UPPER_NOSPACE_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
    
                for m in dictionary_GBE_excluded.keys():
                    #print("")
                    #print("m: ",m)
                    #print("inputcolumnlist_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
                    for n in dictionary_GBE_excluded[m]:
                        #print("n: ",n.replace(' ','').upper())
                        #print("dictionary_GBE[m]: ",dictionary_GBE_excluded[m])
                        #print("******n.replace(' ','').upper(): ",n.replace(' ','').upper())
                        #print("******inputColumnList_UPPER_NOSPACE_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
                        #print(n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE_excluded)
                        
     #                   if n in inputColumnList and n!="Manufacturer name" and n!="Manufacturer number":
                        aindex_excluded=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE_excluded:
                            aindex_excluded = int(inputColumnList_UPPER_NOSPACE_excluded.index(n.replace(' ','').upper()))
                            #print("aindex_excluded: ", aindex_excluded)
                            #print("******list(headers_excluded)[aindex_excluded]: ",list(headers_excluded)[aindex_excluded])

                            #print("-$$---------df_excluded.head----------------")
                            #print("df_excluded.head()",df_excluded.head())
                            
                            #print("-$$----------str--------------")
                            #print("str(list(headers_excluded)[aindex_excluded])",str(list(headers_excluded)[aindex_excluded]))
    
                            df_excluded_tocombine[m] = new_df_excluded[str(list(headers_excluded)[aindex_excluded])]    
    
                self.df3 = pd.DataFrame(pd.concat([self.df3,df_excluded_tocombine]),columns=list(self.df3.columns))         
##################################################################################
                self.df3['# Lines']=1
                self.df3['# Transactions']=0
                self.df3['Current Extended']=0
                self.df3['Current Price']=0

                self.df3 = self.df3.reset_index()
                
#                position1 = new_self.df1.columns.get_loc('Description') + 1
#                position2 = new_self.df1.columns.get_loc('Description') + 2

#                self.df3['Incumbent Manufacturer name'] = new_self.df1[list(new_self.df1.columns)[position1]]
#                self.df3['Incumbent Manufacturer number'] = new_self.df1[list(new_self.df1.columns)[position2]]

#                position3 = new_self.df1.columns.get_loc('Act Price Moderate') + 1
#                position4 = new_self.df1.columns.get_loc('Act Price Moderate') + 2

#                self.df3 = self.df3.set_index(['Incumbent Distributor name'])
# Append to the last row for Non-Benchmarked Spend and Number of Lines
                count_row = self.df3.shape[0]
                #print("count_row: ",count_row)
                self.df3.loc[count_row,'Total incumbent spend'] = self.e9.get()
                self.df3.loc[count_row,'# Lines'] = self.e10.get()
            
#                self.df3.loc[count_row,'CSPL Y/N'] = 'No'
                self.df3.loc[count_row,'Code'] = 'NB'


            
# Append for "Customer Name" Column from user entry

# get user input from "Customer name" in GUI
                self.CustomerNameInput = self.e6.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Customer name'] = self.CustomerNameInput
    
# get user input from "Total incumbent spend" in GUI
#                selfTotalIncumbentSpend = int(self.e6.get())
# assign the values for "Total incumbent spend" column to the input value
#                self.df3['Total incumbent spend'] = selfTotalIncumbentSpend
    

# get user input from "Customer name" in GUI
                self.ProjectNameInput = self.e7.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Project Name'] = self.ProjectNameInput
    
# get user input from "PA Vendor" in GUI
                self.PAVendor = self.c1.get()
                #print("C1: ",self.c1)
# assign the values for "PA Vendor" column to the input value
                self.df3['PA Vendor'] = self.PAVendor
    
# get user input from "Location" in GUI
                self.inputlocation = self.e11.get()
# assign the values for "Location" column to the input value
#                self.df3['Location'] = self.inputlocation
                self.df3['Location'].loc[self.df3['Location'].astype(str).str.upper()=='NAN']=self.inputlocation
    
# get user input from "Date of Benchmark" in GUI
                self.DateOfBenchmark = self.e12.get()
# assign the values for "Date of Benchmark" column to the input value
                self.df3['Date of Benchmark'] = self.DateOfBenchmark
    
 #               if self.rvalue2==1:
#
           #         series3 = self.df3['Incumbent Manufacturer name']
          #          frame5 = {'Incumbent Distributor name':series3}
         #           df8 = pd.DataFrame(frame5)
#       #             df10 = df8.copy()
       #             
      #              df7=self.df3['Incumbent Distributor name'].copy()
     #               self.df3['Incumbent Distributor name']=df8
#   #                 self.df3['Incumbent Distributor name']=df10
   #                 self.df3['Incumbent Manufacturer name']=df7
  #              
 #               if self.rvalue3==1:
#
        #            series4 = self.df3['Incumbent Manufacturer number']
       #             frame6 = {'Incumbent Distributor name':series4}
      #              df9 = pd.DataFrame(frame6)
#    #                df12 = df9.copy()
    #                
   #                 df11 = self.df3['Incumbent Distributor #'].copy()
  #                  self.df3['Incumbent Distributor #']=df9
##                    self.df3['Incumbent Distributor #']=df12
#                    self.df3['Incumbent Manufacturer number'] =df11

# Add last row for Incumbent Distributor name and Incumbent Manufacturer Name

                self.df3.loc[count_row,'Incumbent Distributor name'] = self.df3.loc[count_row-1,'Incumbent Distributor name']
                self.df3.loc[count_row,'Incumbent Manufacturer name'] = self.df3.loc[count_row-1,'Incumbent Manufacturer name']
    
# Stardardize the 'CSPL Y/N'  ('Y','1','True' to 'Yes', 'N','0',"False","" to 'No',)
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='Y']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='N']="No"
        
        
# Standardize the 'Code' ('Description match' to 'DM', 'Exact' to 'E', etc.)
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='EXACT.')]="E"
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='FUNCTION.')]="F"
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='DESCRIPTION.')]="DM"
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='INCOMPLETE.')]="X"
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='DONOTCROSS')]="DNC"
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='OUTOFSYSTEM')]="O"
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='FINDMRO')]="M"
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='NEEDMOREINFO.')]="X"        
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='POTENTIALSOURC.')]="O"
                
#                SpendforNonBenchmark = self.e9.get()
#                self.df3.loc[0,'Non-Benchmarked Spend']=SpendforNonBenchmark        
        
#                numberOfLinesNonBenchmark = self.e10.get()
#                self.df3.loc[0,'Non-Benchmarked Number of lines']=numberOfLinesNonBenchmark



                self.df3 = self.df3.drop(columns=['index'])
    
    
#                self.df3 = self.df3.set_index(['Incumbent Distributor name'])
                
#                self.outputdf = self.df3
#                self.dftoExcel()


	def MBFormatConvertWWGInternal(self):


#==================================Load Excel=================================================

# Get file directory from entry box
                self.fileDirectory1 = self.InputBMFileName

# get sheet name for Item Detail    
                self.sheetName1 = self.c2.get()
#                #print("entry:",self.sheetName1)

# get sheet name for Excluded
                self.sheetName2 = self.c3.get()
                #print("entry3: ", self.sheetName2)

                
                self.rvalue2= self.radio2.get()
#                #print("r2: ",self.rvalue2)
                self.rvalue3= self.radio3.get()
#                #print("r3: ",self.rvalue3)

                
                self.df1= pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName1)

                inputColumnList_original = list(self.df1.loc[0])
                inputColumnList_UPPER_NOSPACE = list(self.df1.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list: ",inputColumnList_UPPER_NOSPACE)

                headers = self.df1.columns
                
                
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(self.df1.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex=0
                if 'CUSTOMERNAME' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'ITEMNUMBER' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'ITEMDESCRIPTION' in list(self.df1.columns.str.replace(' ','').str.upper())or 'SAVINGS%' in list(self.df1.columns.str.replace(' ','').str.upper())or 'UOM' in list(self.df1.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(self.df1.loc[i,:].astype(str).str.replace(' ','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if 'CUSTOMERNAME' in list1 or 'ITEMNUMBER' in list1 or 'ITEMDESCRIPTION' in list1 or 'SAVINGS%' in list1 or 'UOM' in list1:
                            headers = self.df1.iloc[columnHeaderIndex]
                            #print("headers: ",headers)
                            columnHeaderIndex = columnHeaderIndex + 1
                            break            
                        #print("STILL GOING!")
                        if i == 11:
                            messagebox.showwarning("[ITEM Detail] Data Not Copied","[Item Detail] Data Not Copied")                        

                new_df1= pd.DataFrame(self.df1.values[columnHeaderIndex:],columns=headers)
                new_df1.head()
#               headers = self.df1.iloc[0]

#===========================================================================================

#               new_df1 = pd.DataFrame(self.df1.values[1:],columns=headers)

#===================Define Dictionary and set output headers====================================

# Dictionary for aliases for output column names
                dictionary_WWG = {}
# can put 'Distributor Name' for now:
                dictionary_WWG['Incumbent Distributor name'] = ['Distributor Name','Incumbent Distributor name']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_WWG['Incumbent Distributor #'] = ['ITEM NUMBER','Distributor number','Distributor #']
                dictionary_WWG['Incumbent Description'] = ['Description','ITEM DESCRIPTION']
                dictionary_WWG['Incumbent Manufacturer name'] = ['BRAND NAME']
                dictionary_WWG['Incumbent Manufacturer number'] = ['Material','Manufacturer number']
                dictionary_WWG['Incumbent Unit of measure'] = ['Unit of measure']
                dictionary_WWG['Incumbent Units/pack'] = ['Units/pack']
                dictionary_WWG['Incumbent Pack price'] = ['Pack price']
                dictionary_WWG['Incumbent Total packs'] = ['QTY PURCHASED']
                dictionary_WWG['Incumbent Unit price'] = ['Unit price']
                dictionary_WWG['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_WWG['Total incumbent spend'] = ['PURCHASE AMOUNT','Total incumbent spend','Purch Amt']
                dictionary_WWG['Savings $'] = ['Savings $','Savings']
                dictionary_WWG['Savings %'] = ['Savings %']
                dictionary_WWG['Savings cat.'] = ['Savings cat.','Savings Range']
                dictionary_WWG['PA Vendor extended price'] = ['PA Extended','WWG Extended Moderate','WWG Price Ext.','WWG extended price','PA Ext','Lowest Ext','PA Sell ext','PA Sell extended','Ext PA Price']
                dictionary_WWG['PA Vendor unit price'] = ['WWG Unit Price Moderate','WWG Unit Price']
                dictionary_WWG['PA Vendor Item Number item #'] = ['ITEM NUMBER']
                dictionary_WWG['Code'] = ['Match Type','Cross Reference Code','Code']
                dictionary_WWG['Status (in/out)'] = ['Status (in/out)']
                dictionary_WWG['PA Vendor catalog price'] = ['PA Vendor catalog price']
                dictionary_WWG['Act price'] = ['Act Price Moderate','Act price','PA Price','PA COST']
                dictionary_WWG['PA Vendor unit of measure'] = ['WWG unit of measure']
                dictionary_WWG['PA Vendor unit/pack'] = ['WWG unit/pack']
                dictionary_WWG['PA Manufacturer name'] = ['WWG Manufacturer name','WWG Mfg Name','BRAND NAME']
                dictionary_WWG['PA Manufacturer number'] = ['WWG Manufacturer number','WWG Mfg Number']
                dictionary_WWG['PA Vendor Description1'] = ['Description1','WWG Product Description',"WWG Description",'ITEM DESCRIPTION']
                dictionary_WWG['PA Vendor Description2'] = ['Description2']
                dictionary_WWG['PA Vendor Product segment1'] = ['Product segment']
                dictionary_WWG['PA Vendor Product category1'] = ['Product category','MATERIAL CATEGORY']
                dictionary_WWG['PA Vendor Product family1'] = ['Product family']
                dictionary_WWG['CSPL Y/N'] = ['CSP Moderate','CSP','CSP Identification','CSPL']
                dictionary_WWG['Customer name'] = ['']
                dictionary_WWG['Project Name'] = ['']
                dictionary_WWG['PA Vendor'] = ['']
                dictionary_WWG['Location'] = ['Location','CUSTOMER NAME']
                dictionary_WWG['# Lines'] = ['# Lines']
                dictionary_WWG['# Transactions'] = ['# Transactions','TRANSACTIONS']
                
                dictionary_WWG['Current Extended'] = ['Current Extended']
                dictionary_WWG['Current Price'] = ['Current Price']
                dictionary_WWG['Date of Benchmark'] = ['']


                self.df3=pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Savings $','Savings %','Savings cat.',
                'PA Vendor extended price','PA Vendor unit price','PA Vendor Item Number item #','Code','Status (in/out)',
                'PA Vendor catalog price','Act price','PA Vendor unit of measure','PA Vendor unit/pack','PA Manufacturer name',
                'PA Manufacturer number','PA Vendor Description1','PA Vendor Description2','PA Vendor Product segment1','PA Vendor Product category1',
                'PA Vendor Product family1','CSPL Y/N','Customer name','Project Name','PA Vendor','Location','# Lines','# Transactions','Current Extended',
                'Current Price','Date of Benchmark'])

#======================================================================================
            
                inputColumnList_UPPER_NOSPACE = list(headers.astype(str).str.replace(' ','').str.upper())
                
                #print("dictionary_WWG.key: ",dictionary_WWG.keys())
                #print("inputColumnList_UPPER_NOSPACE: ",inputColumnList_UPPER_NOSPACE)

                for m in dictionary_WWG.keys():
                    for n in dictionary_WWG[m]:
                        aindex=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE:
                            aindex = int(inputColumnList_UPPER_NOSPACE.index(n.replace(' ','').upper()))
                            self.df3[m] = new_df1[str(list(headers)[aindex])]
                            
                self.df3['Code']='E'
                
                
                
                
#                self.df3['CSPL Y/N'] = self.df3['CSPL Y/N'].apply(str)
                self.df3['CSPL Y/N'] = self.df3['CSPL Y/N'].astype(str)

                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","")=='1.0']="Yes"    
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","")=='1']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","")=='0']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='Y']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='YES']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='TRUE']="Yes"
#                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N']==0]="No"
#                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N']==1]="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='N']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='NO']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='False']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='NAN']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='']="No"
#                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='']="No"
                
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='TRUEA']="Conditional CSP"
                

##################################################################################
#Excluded file
                df_excluded = pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName2)
    
                inputColumnList_original_excluded = list(df_excluded.loc[0])
                inputColumnList_UPPER_NOSPACE_excluded = list(df_excluded.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)

                headers_excluded = df_excluded.columns    
    
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(df_excluded.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex_excluded=0
                if 'CUSTOMERNAME' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'DESCRIPTION' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'QTY' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'ITEMNUMBER' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'ITEMDESCRIPTION' in list(df_excluded.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(df_excluded.loc[i,:].astype(str).str.replace(' ','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if 'XSORT' in list1 or 'DESCRIPTION' in list1 or 'SAVINGS%' in list1 or 'QTY' in list1 or 'CUSTOMER' in list1:
                            headers_excluded = df_excluded.iloc[columnHeaderIndex]
                            #print("headers_excluded: ",headers_excluded)
                            columnHeaderIndex_excluded = columnHeaderIndex_excluded + 1
                            break            
                        #print("STILL GOING!")    
                        if i == 11:
                            messagebox.showwarning("[Excluded] Data Not Copied","[Excluded] Data Not Copied")    
                new_df_excluded= pd.DataFrame(df_excluded.values[columnHeaderIndex_excluded:],columns=headers_excluded)
                new_df_excluded.head()    
    
    
                dictionary_WWG_excluded = {}
# can put 'Distributor Name' for now:
                dictionary_WWG_excluded['Incumbent Distributor name'] = ['Distributor Name']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_WWG_excluded['Incumbent Distributor #'] = ['ITEM NUMBER']
                dictionary_WWG_excluded['Incumbent Description'] = ['Description','ITEM DISCRIPTION']
                dictionary_WWG_excluded['Incumbent Manufacturer name'] = ['BRAND NAME']
                dictionary_WWG_excluded['Incumbent Manufacturer number'] = ['Material','Manufacturer number','Mfg/Vendor Part Number']
                dictionary_WWG_excluded['Incumbent Unit of measure'] = ['Unit of measure']
                dictionary_WWG_excluded['Incumbent Units/pack'] = ['Units/pack']
                dictionary_WWG_excluded['Incumbent Pack price'] = ['Pack price']
                dictionary_WWG_excluded['Incumbent Total packs'] = ['QTY PURCHASED']
                dictionary_WWG_excluded['Incumbent Unit price'] = ['Unit price']
                dictionary_WWG_excluded['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_WWG_excluded['Total incumbent spend'] = ['PURCHASE AMOUNT','Purch Amt']
                dictionary_WWG_excluded['Code'] = ['Notes','PA Price','PA Cost']
    
                df_excluded_tocombine = pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Code'])    
    
                inputColumnList_UPPER_NOSPACE_excluded = list(headers_excluded.astype(str).str.replace(' ','').str.upper())
        
                #print("dictionary_WWG.key_excluded: ",dictionary_WWG_excluded.keys()) 
                #print("inputColumnList_UPPER_NOSPACE_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
    
                for m in dictionary_WWG_excluded.keys():
                    for n in dictionary_WWG_excluded[m]:
                        
     #                   if n in inputColumnList and n!="Manufacturer name" and n!="Manufacturer number":
                        aindex_excluded=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE_excluded:
                            aindex_excluded = int(inputColumnList_UPPER_NOSPACE_excluded.index(n.replace(' ','').upper()))
                            #print("aindex_excluded: ", aindex_excluded)
                            #print("******list(headers_excluded)[aindex_excluded]: ",list(headers_excluded)[aindex_excluded])

                            #print("-$$---------df_excluded.head----------------")
                            #print("df_excluded.head()",df_excluded.head())
                            
                            #print("-$$----------str--------------")
                            #print("str(list(headers_excluded)[aindex_excluded])",str(list(headers_excluded)[aindex_excluded]))
    
                            df_excluded_tocombine[m] = new_df_excluded[str(list(headers_excluded)[aindex_excluded])]    
    
                self.df3 = pd.DataFrame(pd.concat([self.df3,df_excluded_tocombine]),columns=list(self.df3.columns))    
    

##################################################################################
                self.df3['# Lines']=1
#                self.df3['# Transactions']=0
#                self.df3['Current Extended']=0
#                self.df3['Current Price']=0

                self.df3 = self.df3.reset_index()
# Standardize the 'Code' ('Description match' to 'DM', 'Exact' to 'E', etc.)
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='SOURCEDITE.')]="S"
# Standardize the 'Code' ('NOT ACTIVE' to 'D' <Discontinued>)
#                self.df3['Code'].loc[self.df3['Code'].astype(str).str.replace(" ","").str.replace("-","").str.upper().str.match(pat='NOTACTIV.')]="DISC"
# Standardize the 'Code' (All numbers to 'R' <Return>)
#                self.df3['Code'].loc[self.df3.applymap(lambda x: isinstance(x, (int,float)))['Code']==True]='R' 
#                self.df3['Code'].loc[self.df3['Code']!=0].loc[self.df3.applymap(lambda x: isinstance(x, (int,float)))['Code']==True]='R'
    
                count_row = self.df3.shape[0]
                #print("count_row: ",count_row)
            
# Append for "Customer Name" Column from user entry

# get user input from "Customer name" in GUI
                self.CustomerNameInput = self.e6.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Customer name'] = self.CustomerNameInput
    
# get user input from "Total incumbent spend" in GUI
#                selfTotalIncumbentSpend = int(self.e6.get())
# assign the values for "Total incumbent spend" column to the input value
#                self.df3['Total incumbent spend'] = selfTotalIncumbentSpend
    

# get user input from "Customer name" in GUI
                self.ProjectNameInput = self.e7.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Project Name'] = self.ProjectNameInput
    
# get user input from "PA Vendor" in GUI
                self.PAVendor = self.c1.get()
                #print("C1: ",self.c1)
# assign the values for "PA Vendor" column to the input value
                self.df3['PA Vendor'] = self.PAVendor
    
# get user input from "Location" in GUI
#                self.inputlocation = self.e11.get()
# assign the values for "Location" column to the input value
#                self.df3['Location'] = self.inputlocation

# get user input from "PA Vendor" in GUI
                self.PAVendor = self.c1.get()
#                #print("C1: ",self.c1)
# assign the values for "Incumbent Distributor name" column to the input value
                self.df3['Incumbent Distributor name'] = self.PAVendor

# get user input from "Date of Benchmark" in GUI
                self.DateOfBenchmark = self.e12.get()
# assign the values for "Date of Benchmark" column to the input value
                self.df3['Date of Benchmark'] = self.DateOfBenchmark

# Stardardize the 'CSPL Y/N'  ('Y','1','True' to 'Yes', 'N','0',"False","" to 'No',)
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='Y']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='N']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N']==1]="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='0']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=="'TRUE"]="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=="'"]="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='TRUE']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='FALSE']="No"
                

#                SpendforNonBenchmark = self.e9.get()
#                self.df3.loc[0,'Non-Benchmarked Spend']=SpendforNonBenchmark        
        
#                numberOfLinesNonBenchmark = self.e10.get()
#                self.df3.loc[0,'Non-Benchmarked Number of lines']=numberOfLinesNonBenchmark
                self.df3 = self.df3.drop(columns=['index'])
    
#                self.df3 = self.df3.set_index(['Incumbent Distributor name'])

#                self.outputdf = self.df3
#                self.dftoExcel()


	def whetherSwitchManufacturerDistributor(self):
## If needed, can choose to Switch "Manufacture Name" with "Distributor Name"   AND/OR    Switch "Manufacture Number" with "Distributor Number"

		self.rvalue2= self.radio2.get()
		self.rvalue3= self.radio3.get()
        
		print("===============self.df3.columns: ", self.df3.columns)
        
        
		if self.BMFileType == 'External':
			if self.rvalue2==1:

			    series3 = self.df3['Incumbent Manufacturer name']
			    frame5 = {'Incumbent Distributor name':series3}
			    self.df8 = pd.DataFrame(frame5)
#                    df10 = df8.copy()

			    self.df7=self.df3['Incumbent Distributor name'].copy()
			    self.df3['Incumbent Distributor name']=self.df8
#                    self.df3['Incumbent Distributor name']=df10
			    self.df3['Incumbent Manufacturer name']=self.df7

			if self.rvalue3==1:

				series4 = self.df3['Incumbent Manufacturer number']
				frame6 = {'Incumbent Distributor name':series4}
				df9 = pd.DataFrame(frame6)
#                    df12 = df9.copy()

				df11 = self.df3['Incumbent Distributor #'].copy()
    
				self.df3['Incumbent Distributor #']=df9
#                    self.df3['Incumbent Distributor #']=df12
				self.df3['Incumbent Manufacturer number'] =df11
    
# get user input from "Incumbent Distributor name" in GUI
		self.inputIncumbentDistributorName = self.e16.get()
# assign the values for "Location" column to the input value
#                self.df3['Location'] = self.inputlocation
		self.df3['Incumbent Distributor name'].loc[self.df3['Incumbent Distributor name'].astype(str).str.upper()=='NAN']=self.inputIncumbentDistributorName
    
#		self.df3 = self.df3.drop(columns=['index'])
#		self.df3 = self.df3.set_index(['Incumbent Distributor name'])
            
	def dftoExcel(self):
		self.MBFormatConvertor()
		self.whetherSwitchManufacturerDistributor()
		self.df3 = self.df3.set_index(['Incumbent Distributor name'])
		continueExportFile = False
		outputFolderDirectory = self.e4.get()
		self.outputFileName = self.e5.get()
		#print("self.outputFileName: ",self.outputFileName)
		outputExcelFileName = self.outputFileName+".xlsx"
		#print("outputExcelFileName: ",outputExcelFileName)
        
#		#print(folderDirectory)
		outputFolderfilesNames = os.listdir(outputFolderDirectory)
		#print(outputFolderfilesNames)

		if (outputExcelFileName in outputFolderfilesNames):
			#print("Same name file!!!!!!!!!")
			whetherOverwrite = messagebox.askyesno("Overwrite?", "The output file name already exists in this folder, do you want to overwrite the previous file? \n \nYes - to overwrite the previous file \nNo - to change the Output file name or Folder")
			if whetherOverwrite == True:
				continueExportFile = True
			elif whetherOverwrite == False:
				pass
        
		else:            
			continueExportFile = True
        
        
        
		if continueExportFile == True:
            
        #                #print("e4:"+"/",self.outputFileName)
			self.outputFileDirectory = self.OutputfileNameMB +"/"+self.outputFileName+".xlsx"
        #                #print(self.outputFileDirectory)

			writer = pd.ExcelWriter(self.outputFileDirectory)

			self.df3.to_excel(writer,sheet_name='Master Template')
			writer.save()
			self.theStr = "The converted Excel file has been created!"
			messagebox.showinfo("Exported Successfully", self.theStr)
			os.startfile(self.outputFileDirectory)


	def MBFormatConvertWWGExternal(self):
#                #print(self.InputBMFileName)
#                #print(self.OutputfileNameMB)

#==================================Load Excel=================================================

# Get file directory from entry box
                self.didNotCopyList_ItemDetail = []
    
                self.important_columns_ItemDetail = ['Incumbent Distributor name',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Code','PA Vendor unit of measure','PA Vendor unit/pack',
                'PA Vendor Product segment1','PA Vendor Product category1',
                'PA Vendor Product family1','CSPL Y/N','Savings $','Savings %','Savings Cat.','PA Vendor extended price']
        
                self.didNotCopyList_Excluded = []
        
                self.important_columns_Excluded = ['Incumbent Distributor name',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Code']

                self.fileDirectory1 = self.InputBMFileName

# get sheet name for Item Detail    
                self.sheetName1 = self.c2.get()
#                #print("entry:",self.sheetName1)

# get sheet name for Excluded
                self.sheetName2 = self.c3.get()
                #print("entry3: ", self.sheetName2)

                
                self.rvalue2= self.radio2.get()
#                #print("r2: ",self.rvalue2)
                self.rvalue3= self.radio3.get()
#                #print("r3: ",self.rvalue3)

                
                self.df1= pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName1)

                inputColumnList_original = list(self.df1.loc[0])
                inputColumnList_UPPER_NOSPACE = list(self.df1.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list: ",inputColumnList_UPPER_NOSPACE)

                headers = self.df1.columns
                
                
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(self.df1.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex=0
                if 'XSORT' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'SEQUENCE#' in list(self.df1.columns.str.replace(' ','').str.upper()) or 'DESCRIPTION' in list(self.df1.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(self.df1.loc[i,:].astype(str).str.replace(' ','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if 'XSORT' in list1 or 'DESCRIPTION' in list1 or 'SAVINGS%' in list1:
                            headers = self.df1.iloc[columnHeaderIndex]
                            #print("headers: ",headers)
                            columnHeaderIndex = columnHeaderIndex + 1
                            break            
                        #print("STILL GOING!")
                        if i == 11:
                            messagebox.showwarning("[ITEM Detail] Data Not Copied","[Item Detail] Data Not Copied")



                
#               #print(columnHeaderIndex)
#               #print("Headers: ",headers)
                new_df1= pd.DataFrame(self.df1.values[columnHeaderIndex:],columns=headers)
                new_df1.head()
#               headers = self.df1.iloc[0]

#===========================================================================================

#               new_df1 = pd.DataFrame(self.df1.values[1:],columns=headers)

#===================Define Dictionary and set output headers====================================

# Dictionary for aliases for output column names
                dictionary_WWG = {}
# can put 'Distributor Name' for now:
                dictionary_WWG['Incumbent Distributor name'] = ['Distributor Name','Incumbent Distributor name']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_WWG['Incumbent Distributor #'] = ['Distributor Part Number',"Distributor number", "Distributor #"]
                dictionary_WWG['Incumbent Description'] = ['Description','Detailed Item Description','ITEM DESCRIPTION']
                dictionary_WWG['Incumbent Manufacturer name'] = ['Manufacturer name','Mfg/Vendor Name']
                dictionary_WWG['Incumbent Manufacturer number'] = ['Manufacturer number','Mfg/Vendor Part Number']
                dictionary_WWG['Incumbent Unit of measure'] = ['Unit of measure']
                dictionary_WWG['Incumbent Units/pack'] = ['Units/pack']
                dictionary_WWG['Incumbent Pack price'] = ['Pack price']
                dictionary_WWG['Incumbent Total packs'] = ['Total packs']
                dictionary_WWG['Incumbent Unit price'] = ['Unit price']
                dictionary_WWG['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_WWG['Total incumbent spend'] = ['Total incumbent spend','Price Ext.']
                dictionary_WWG['Savings $'] = ['Savings $','Rebated Savings $']
                dictionary_WWG['Savings %'] = ['Savings %','Rebated Savings %']
                dictionary_WWG['Savings cat.'] = ['Savings cat.','Savings Category','Rebated Savings Category']
                dictionary_WWG['PA Vendor extended price'] = ['WWG Extended Moderate','WWG Price Ext.','WWG extended price','PA Ext','PA Extended','Lowest Ext','PA Sell ext','PA Sell extended','Ext PA Price']
                dictionary_WWG['PA Vendor unit price'] = ['WWG Unit Price Moderate','WWG Unit Price']
                dictionary_WWG['PA Vendor Item Number item #'] = ['WWG Item Moderate',"WWG item #"]
                dictionary_WWG['Code'] = ['Code','Cross Reference Code','Match Type']
                dictionary_WWG['Status (in/out)'] = ['Status (in/out)']
                dictionary_WWG['PA Vendor catalog price'] = ['PA Vendor catalog price']
                dictionary_WWG['Act price'] = ['Act Price Moderate','Act price']
                dictionary_WWG['PA Vendor unit of measure'] = ['WWG unit of measure']
                dictionary_WWG['PA Vendor unit/pack'] = ['WWG unit/pack']
                dictionary_WWG['PA Manufacturer name'] = ['WWG Manufacturer name','WWG Mfg Name']
                dictionary_WWG['PA Manufacturer number'] = ['WWG Manufacturer number','WWG Mfg Number']
                dictionary_WWG['PA Vendor Description1'] = ['Description1','WWG Description','WWG Product Description']
                dictionary_WWG['PA Vendor Description2'] = ['Description2']
                dictionary_WWG['PA Vendor Product segment1'] = ['Product segment']
                dictionary_WWG['PA Vendor Product category1'] = ['Product category','MATERIAL CATEGORY']
                dictionary_WWG['PA Vendor Product family1'] = ['Product family']
                dictionary_WWG['CSPL Y/N'] = ['CSP Moderate','CSP','CSP Identification']
                dictionary_WWG['Customer name'] = ['']
                dictionary_WWG['Project Name'] = ['']
                dictionary_WWG['PA Vendor'] = ['']
                dictionary_WWG['Location'] = ['Location']
                dictionary_WWG['# Lines'] = ['# Lines']
                dictionary_WWG['# Transactions'] = ['# Transactions','TRANSACTIONS']
                dictionary_WWG['Current Extended'] = ['Current Extended']
                dictionary_WWG['Current Price'] = ['Current Price']
                dictionary_WWG['Date of Benchmark'] = ['']


                self.df3=pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Savings $','Savings %','Savings cat.',
                'PA Vendor extended price','PA Vendor unit price','PA Vendor Item Number item #','Code','Status (in/out)',
                'PA Vendor catalog price','Act price','PA Vendor unit of measure','PA Vendor unit/pack','PA Manufacturer name',
                'PA Manufacturer number','PA Vendor Description1','PA Vendor Description2','PA Vendor Product segment1','PA Vendor Product category1',
                'PA Vendor Product family1','CSPL Y/N','Customer name','Project Name','PA Vendor','Location','# Lines','# Transactions','Current Extended',
                'Current Price','Date of Benchmark'])
#                self.df3[]=
#                self.df3[]=                
#                self.df3[]=
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                
#                self.df3[]=                

                #print("-------------self.df3.head----------------")
                #print(self.df3.head())
        
                #print("-------------new_self.df1.head----------------")
                #print(new_df1.head())
        
                #print("-------------new_self.df1.columns----------------")
                #print(new_df1.columns)

                #print("-------------headers----------------")
                #print(headers)

#======================================================================================
            
                inputColumnList_UPPER_NOSPACE = list(headers.astype(str).str.replace(' ','').str.upper())
                
                #print("dictionary_WWG.key: ",dictionary_WWG.keys())
                #print("inputColumnList_UPPER_NOSPACE: ",inputColumnList_UPPER_NOSPACE)

                for m in dictionary_WWG.keys():
                    #print("")
                    #print("m: ",m)
                    #print("inputcolumnlist: ",inputColumnList_UPPER_NOSPACE)
                    
                    occurance = 0
                    for n in dictionary_WWG[m]:
                        #print("n: ",n.replace(' ','').upper())
                        #print("dictionary_WWG[m]: ",dictionary_WWG[m])
                        #print("******n.replace(' ','').upper(): ",n.replace(' ','').upper())
                        #print("******inputColumnList_UPPER_NOSPACE: ",inputColumnList_UPPER_NOSPACE)
                        #print(n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE)
                        
     #                   if n in inputColumnList and n!="Manufacturer name" and n!="Manufacturer number":
                        aindex=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE:
                            aindex = int(inputColumnList_UPPER_NOSPACE.index(n.replace(' ','').upper()))
                            #print("aindex: ", aindex)
                            #print("******list(headers)[aindex]: ",list(headers)[aindex])

                            #print("-$$---------self.df3.head----------------")
                            #print("self.df3.head()",self.df3.head())
                            
                            #print("-$$----------str--------------")
                            #print("str(list(headers)[aindex])",str(list(headers)[aindex]))
    
                            self.df3[m] = new_df1[str(list(headers)[aindex])]
                            occurance+=1
                    if occurance==0:
                        self.didNotCopyList_ItemDetail.append(m)
#                        else:
#                            self.df3[m] = "to be created"
                
                self.importantMissingColumnList_ItemDetail = list(set(self.didNotCopyList_ItemDetail) & set(self.important_columns_ItemDetail))
#                print("******self.didNotCopyList_ItemDetail: ",self.didNotCopyList_ItemDetail)
#                print("%%%%%%%%%%%self.importantMissingColumnList_ItemDetail: ",self.importantMissingColumnList_ItemDetail)
                self.stringForImportantMissingColumns = "; ".join(self.importantMissingColumnList_ItemDetail)

#                self.df3['CSPL Y/N'] = self.df3['CSPL Y/N'].apply(str)
                self.df3['CSPL Y/N'] = self.df3['CSPL Y/N'].astype(str)

                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","")=='1.0']="Yes"    
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","")=='1']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","")=='0']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='Y']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='YES']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='TRUE']="Yes"
#                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N']==0]="No"
#                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N']==1]="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='N']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='NO']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='False']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='NAN']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.replace(" ","").str.upper()=='']="No"
#                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='']="No"
                
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='TRUEA']="Conditional CSP"
##################################################################################
#Excluded file
                df_excluded = pd.read_excel(self.fileDirectory1,sheet_name=self.sheetName2)
    
                inputColumnList_original_excluded = list(df_excluded.loc[0])
                inputColumnList_UPPER_NOSPACE_excluded = list(df_excluded.loc[0].astype(str).str.replace(' ','').str.upper())
                #print("input Column list_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)

                headers_excluded = df_excluded.columns    
    
                #print("++++++list(self.df1.columns.str.replace(' ','').str.upper()): ",list(df_excluded.columns.str.replace(' ','').str.upper()))
                columnHeaderIndex_excluded=0
                if 'XSORT' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'SEQUENCE#' in list(df_excluded.columns.str.replace(' ','').str.upper()) or 'DESCRIPTION' in list(df_excluded.columns.str.replace(' ','').str.upper()):
                    #print("################PASS!!!")
                    pass
                else:
                    for i in range(12):
                        columnHeaderIndex=i
                        list1 = list(df_excluded.loc[i,:].astype(str).str.replace(' ','').str.upper())
                        #print("round ", i)
                        #print("list1: ",list1)
                        if 'XSORT' in list1 or 'ESCRIPTION' in list1 or 'SAVINGS%' in list1:
                            headers_excluded = df_excluded.iloc[columnHeaderIndex]
                            #print("headers_excluded: ",headers_excluded)
                            columnHeaderIndex_excluded = columnHeaderIndex_excluded + 1
                            break            
                        #print("STILL GOING!")
                        if i == 11:
                            messagebox.showwarning("[Excluded] Data Not Copied","[Excluded] Data Not Copied")
    
                new_df_excluded= pd.DataFrame(df_excluded.values[columnHeaderIndex_excluded:],columns=headers_excluded)
                new_df_excluded.head()    
    
    
                dictionary_WWG_excluded = {}
# can put 'Distributor Name' for now:
                dictionary_WWG_excluded['Incumbent Distributor name'] = ['Distributor Name','Incumbent Distributor name']
# can put 'Distributor #' and 'Distributor number' for now:
                dictionary_WWG_excluded['Incumbent Distributor #'] = ['Distributor Part Number']
                dictionary_WWG_excluded['Incumbent Description'] = ['Description','Detailed Item Description']
                dictionary_WWG_excluded['Incumbent Manufacturer name'] = ['Manufacturer name','Mfg/Vendor Name']
                dictionary_WWG_excluded['Incumbent Manufacturer number'] = ['Manufacturer number','Mfg/Vendor Part Number']
                dictionary_WWG_excluded['Incumbent Unit of measure'] = ['Unit of measure']
                dictionary_WWG_excluded['Incumbent Units/pack'] = ['Units/pack']
                dictionary_WWG_excluded['Incumbent Pack price'] = ['Pack price']
                dictionary_WWG_excluded['Incumbent Total packs'] = ['Total packs']
                dictionary_WWG_excluded['Incumbent Unit price'] = ['Unit price']
                dictionary_WWG_excluded['Total Incumbent baseline units'] = ['Total baseline units']
                dictionary_WWG_excluded['Total incumbent spend'] = ['Total incumbent spend','Price Ext.','Purchase Amount','Purch Amt']
                dictionary_WWG_excluded['Code'] = ['Notes','Cross Reference Code','Code']    
    
                df_excluded_tocombine = pd.DataFrame(columns=['Incumbent Distributor name','Incumbent Distributor #','Incumbent Description',
                'Incumbent Manufacturer name','Incumbent Manufacturer number','Incumbent Unit of measure',
                'Incumbent Units/pack','Incumbent Pack price','Incumbent Total packs','Incumbent Unit price',
                'Total Incumbent baseline units','Total incumbent spend','Code'])    
    
                inputColumnList_UPPER_NOSPACE_excluded = list(headers_excluded.astype(str).str.replace(' ','').str.upper())
        
                #print("dictionary_WWG.key_excluded: ",dictionary_WWG_excluded.keys()) 
                #print("inputColumnList_UPPER_NOSPACE_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
    
                for m in dictionary_WWG_excluded.keys():
                    #print("")
                    #print("m: ",m)
                    #print("inputcolumnlist_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
                    occurance_excluded = 0
                    for n in dictionary_WWG_excluded[m]:
                        #print("n: ",n.replace(' ','').upper())
                        #print("dictionary_WWG[m]: ",dictionary_WWG_excluded[m])
                        #print("******n.replace(' ','').upper(): ",n.replace(' ','').upper())
                        #print("******inputColumnList_UPPER_NOSPACE_excluded: ",inputColumnList_UPPER_NOSPACE_excluded)
                        #print(n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE_excluded)
                        
     #                   if n in inputColumnList and n!="Manufacturer name" and n!="Manufacturer number":
                        aindex_excluded=0
                        if n.replace(' ','').upper() in inputColumnList_UPPER_NOSPACE_excluded:
                            aindex_excluded = int(inputColumnList_UPPER_NOSPACE_excluded.index(n.replace(' ','').upper()))
                            #print("aindex_excluded: ", aindex_excluded)
                            #print("******list(headers_excluded)[aindex_excluded]: ",list(headers_excluded)[aindex_excluded])

                            #print("-$$---------df_excluded.head----------------")
                            #print("df_excluded.head()",df_excluded.head())
                            
                            #print("-$$----------str--------------")
                            #print("str(list(headers_excluded)[aindex_excluded])",str(list(headers_excluded)[aindex_excluded]))
    
                            df_excluded_tocombine[m] = new_df_excluded[str(list(headers_excluded)[aindex_excluded])]
                            occurance_excluded+=1
                    if occurance==0:
                        self.didNotCopyList_ItemDetail.append(m)
                        
                self.importantMissingColumnList_Excluded = list(set(self.didNotCopyList_Excluded) & set(self.important_columns_Excluded))
#                print("******self.didNotCopyList_ItemDetail: ",self.didNotCopyList_ItemDetail)
#                print("%%%%%%%%%%%self.importantMissingColumnList_Excluded: ",self.importantMissingColumnList_Excluded)
                self.stringForImportantMissingColumns_Excluded = "; ".join(self.importantMissingColumnList_Excluded)
        
                self.messageForImportantMissingColumns = "Important missing column(s): \n\n[Item Detail]: " + self.stringForImportantMissingColumns + "\n[Excluded]: " + self.stringForImportantMissingColumns_Excluded  + "\n\nPlease check them before exporting."
#                print("************self.messageForImportantMissingColumns: ",self.messageForImportantMissingColumns)
 #               self.messageForImportantMissingColumns_Excluded = "Important missing column(s): \n\n[Excluded]: " + self.stringForImportantMissingColumns + "\n\nPlease check them before exporting."
 #               print("************self.messageForImportantMissingColumns: ",self.messageForImportantMissingColumns)
            
            
    
                self.df3 = pd.DataFrame(pd.concat([self.df3,df_excluded_tocombine]),columns=list(self.df3.columns))    
    

##################################################################################
                self.df3['# Lines']=1
                self.df3['Current Extended']=0
                self.df3['Current Price']=0

                self.df3 = self.df3.reset_index()
                
#                position1 = new_self.df1.columns.get_loc('Description') + 1
#                position2 = new_self.df1.columns.get_loc('Description') + 2

#                self.df3['Incumbent Manufacturer name'] = new_self.df1[list(new_self.df1.columns)[position1]]
#                self.df3['Incumbent Manufacturer number'] = new_self.df1[list(new_self.df1.columns)[position2]]

#                position3 = new_self.df1.columns.get_loc('Act Price Moderate') + 1
#                position4 = new_self.df1.columns.get_loc('Act Price Moderate') + 2

#                self.df3 = self.df3.set_index(['Incumbent Distributor name'])
# Append to the last row for Non-Benchmarked Spend and Number of Lines
                count_row = self.df3.shape[0]
                #print("count_row: ",count_row)
                self.df3.loc[count_row,'Total incumbent spend'] = self.e9.get()
                self.df3.loc[count_row,'# Lines'] = self.e10.get()
            
#                self.df3.loc[count_row,'CSPL Y/N'] = 'No'
                self.df3.loc[count_row,'Code'] = 'NB'

    

            
# Append for "Customer Name" Column from user entry

# get user input from "Customer name" in GUI
                self.CustomerNameInput = self.e6.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Customer name'] = self.CustomerNameInput
    
# get user input from "Total incumbent spend" in GUI
#                selfTotalIncumbentSpend = int(self.e6.get())
# assign the values for "Total incumbent spend" column to the input value
#                self.df3['Total incumbent spend'] = selfTotalIncumbentSpend
    

# get user input from "Customer name" in GUI
                self.ProjectNameInput = self.e7.get()
# assign the values for "Customer Name" column to the input value
                self.df3['Project Name'] = self.ProjectNameInput
    
# get user input from "PA Vendor" in GUI
                self.PAVendor = self.c1.get()
                #print("C1: ",self.c1)
# assign the values for "PA Vendor" column to the input value
                self.df3['PA Vendor'] = self.PAVendor
    
# get user input from "Location" in GUI
                self.inputlocation = self.e11.get()
# assign the values for "Location" column to the input value
#                self.df3['Location'] = self.inputlocation
                self.df3['Location'].loc[self.df3['Location'].astype(str).str.upper()=='NAN']=self.inputlocation



    
# get user input from "Date of Benchmark" in GUI
                self.DateOfBenchmark = self.e12.get()
# assign the values for "Date of Benchmark" column to the input value
                self.df3['Date of Benchmark'] = self.DateOfBenchmark


#                series1 = new_self.df1.iloc[:,position3]
#                series2 = new_self.df1.iloc[:,position4]
                
#                frame1 = {'PA Manufacturer name':series1}
#                frame2 = {'PA Manufacturer number':series2}

#                df5 = pd.DataFrame(frame1)
#                df6 = pd.DataFrame(frame2)
                    
#                self.df3['PA Manufacturer name'] = df5
#                self.df3['PA Manufacturer number'] = df6

#                if self.rvalue2==1:

           #         series3 = self.df3['Incumbent Manufacturer name']
          #          frame5 = {'Incumbent Distributor name':series3}
         #           df8 = pd.DataFrame(frame5)
#       #             df10 = df8.copy()
       #             
      #              df7=self.df3['Incumbent Distributor name'].copy()
     #               self.df3['Incumbent Distributor name']=df8
#   #                 self.df3['Incumbent Distributor name']=df10
   #                 self.df3['Incumbent Manufacturer name']=df7
  #              
 #               if self.rvalue3==1:
#
     #               series4 = self.df3['Incumbent Manufacturer number']
    #                frame6 = {'Incumbent Distributor name':series4}
   #                 df9 = pd.DataFrame(frame6)
#                    df12 = df9.copy()
  #                  
 #                   df11 = self.df3['Incumbent Distributor #'].copy()
#                    self.df3['Incumbent Distributor #']=df9
#                    self.df3['Incumbent Distributor #']=df12
#                    self.df3['Incumbent Manufacturer number'] =df11

# Add last row for Incumbent Distributor name and Incumbent Manufacturer Name

                self.df3.loc[count_row,'Incumbent Distributor name'] = self.df3.loc[count_row-1,'Incumbent Distributor name']
                self.df3.loc[count_row,'Incumbent Manufacturer name'] = self.df3.loc[count_row-1,'Incumbent Manufacturer name']
    
# Stardardize the 'CSPL Y/N'  ('Y','1','True' to 'Yes', 'N','0',"False","" to 'No',)

                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='Y']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='N']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str)=='1']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='0']="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=="'TRUE"]="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=="'"]="No"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='TRUE']="Yes"
                self.df3['CSPL Y/N'].loc[self.df3['CSPL Y/N'].astype(str).str.upper()=='FALSE']="No"
                
                
        
                
#                SpendforNonBenchmark = self.e9.get()
#                self.df3.loc[0,'Non-Benchmarked Spend']=SpendforNonBenchmark        
        
#                numberOfLinesNonBenchmark = self.e10.get()
#                self.df3.loc[0,'Non-Benchmarked Number of lines']=numberOfLinesNonBenchmark

                self.df3 = self.df3.drop(columns=['index'])
    
    
#                self.df3 = self.df3.set_index(['Incumbent Distributor name'])
                
#                self.outputdf = self.df3
#                #print(self.df3.head(20))
#                self.dftoExcel()

MasterBenchmark()
		
# Please ask Xing if you have questions
# Out:
# C:\Users\xing.shen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2775: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# ...
# ======================================Preview of New File Below========================================
# ...
#    Incumbent Distributor name Incumbent Distributor #  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# 5                         NaN                     NaN
# 6                         NaN                     NaN
# 7                         NaN                     NaN
# ...
