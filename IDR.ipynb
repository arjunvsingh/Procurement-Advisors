# %%
import pandas as pd
import numpy as np

# %%
df_jan_feb_mar = pd.read_csv("IDR_GUS_Jan Feb March 2019.PA.Full.csv",encoding= 'utf-8',low_memory=False)

# %%
df_jan_feb_mar
# Out:
#                            ACCOUNT NAME  STRATEGIC ACCOUNT DIVISION NAME  \
# 0                      SEAWORLD ORLANDO                         SEAWORLD
# 1        AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 2        AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 3        AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 4        AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 5        AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 6        AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 7              EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 8              EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 9              EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 10             EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 11                         GERDAU MILLS                           GERDAU
# ...

# %%
df_apr_may = pd.read_csv("IDR_GUS_April May 2019.PA.Full.csv",encoding= 'utf-8',low_memory=False)

# %%
df_apr_may
# Out:
#                             ACCOUNT NAME STRATEGIC ACCOUNT DIVISION NAME  \
# 0                    DART CONTAINER CORP                  DART CONTAINER
# 1                         DART CONTAINER                  DART CONTAINER
# 2                         DART CONTAINER                  DART CONTAINER
# 3                         DART CONTAINER                  DART CONTAINER
# 4                         DART CONTAINER                  DART CONTAINER
# 5                         DART CONTAINER                  DART CONTAINER
# 6                         DART CONTAINER                  DART CONTAINER
# 7                         DART CONTAINER                  DART CONTAINER
# 8                         DART CONTAINER                  DART CONTAINER
# 9                         DART CONTAINER                  DART CONTAINER
# 10      DART CONTAINER CORP OF KY BLDG 1                  DART CONTAINER
# 11                        DART CONTAINER                  DART CONTAINER
# ...

# %%
df_jun_jul = pd.read_csv("IDR.GUS.June July 2019.PA.full.csv",encoding= 'utf-8',low_memory=False)

# %%
df_jun_jul
# Out:
#                             ACCOUNT NAME STRATEGIC ACCOUNT DIVISION NAME  \
# 0          LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 1          LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 2          LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 3          LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 4          LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 5          LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 6          LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 7          LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 8          LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 9          LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 10         LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# 11         LKQ/KEYSTONE-BRAINERD/VENDING                 LKQ CORPORATION
# ...

# %%
df_aug_sept = pd.read_csv("IDR_GUS_Aug Sept 2019.PA.Full.csv",encoding= 'utf-8',low_memory=False)

# %%
df_aug_sept
# Out:
#              ACCOUNT NAME STRATEGIC ACCOUNT DIVISION NAME  ACCOUNT NUMBER  \
# 0             CORNING INC                         CORNING       800010126
# 1             CORNING INC                         CORNING       800010126
# 2             CORNING INC                         CORNING       800010126
# 3             CORNING INC                         CORNING       800010126
# 4             CORNING INC                         CORNING       800010126
# 5             CORNING INC                         CORNING       800010126
# 6             CORNING INC                         CORNING       800010126
# 7             CORNING INC                         CORNING       800010126
# 8             CORNING INC                         CORNING       800010126
# 9             CORNING INC                         CORNING       800010126
# 10            CORNING INC                         CORNING       800010126
# 11            CORNING INC                         CORNING       800010126
# ...

# %%
df_oct_nov = pd.read_csv("IDR_GUS_Oct Nov 2019.PA.Full.csv",encoding= 'utf-8',low_memory=False)

# %%
df_oct_nov
# Out:
#                         ACCOUNT NAME STRATEGIC ACCOUNT DIVISION NAME  \
# 0                        CORNING INC                         CORNING
# 1                        CORNING INC                         CORNING
# 2                        CORNING INC                         CORNING
# 3                        CORNING INC                         CORNING
# 4                        CORNING INC                         CORNING
# 5                        CORNING INC                         CORNING
# 6                        CORNING INC                         CORNING
# 7                        CORNING INC                         CORNING
# 8                        CORNING INC                         CORNING
# 9                        CORNING INC                         CORNING
# 10                       CORNING INC                         CORNING
# 11                       CORNING INC                         CORNING
# 12                       CORNING INC                         CORNING
# ...

# %%
df_dec = pd.read_csv("IDR_GUS_December2019.PA.full.csv",encoding= 'utf-8',low_memory=False)

# %%
df_dec
# Out:
#                             ACCOUNT NAME STRATEGIC ACCOUNT DIVISION NAME  \
# 0                            CORNING INC                         CORNING
# 1                            CORNING INC                         CORNING
# 2                            CORNING INC                         CORNING
# 3                            CORNING INC                         CORNING
# 4                            CORNING INC                         CORNING
# 5                            CORNING INC                         CORNING
# 6                            CORNING INC                         CORNING
# 7                            CORNING INC                         CORNING
# 8                            CORNING INC                         CORNING
# 9                            CORNING INC                         CORNING
# 10                           CORNING INC                         CORNING
# 11                           CORNING INC                         CORNING
# ...

# %%
df_combined_test1 = pd.concat([df_jan_feb_mar,df_apr_may,df_jun_jul,df_aug_sept,df_oct_nov,df_dec],sort=False)

# %%
df_combined_test1
# Out:
#                             ACCOUNT NAME  STRATEGIC ACCOUNT DIVISION NAME  \
# 0                       SEAWORLD ORLANDO                         SEAWORLD
# 1         AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 2         AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 3         AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 4         AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 5         AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 6         AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 7               EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 8               EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 9               EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 10              EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 11                          GERDAU MILLS                           GERDAU
# ...

# %%
df_combined.test1.columns
# Out:
# Index(['ACCOUNT NAME', 'STRATEGIC ACCOUNT DIVISION NAME', 'ACCOUNT NUMBER',
#        'SHIPPING CITY', 'SHIPPING STATE', 'Manufacturer Code',
#        'MANUFACTURER NAME', 'MANUFACTURER PART NUMBER',
#        'PRODUCT GROUP DESCRIPTION', 'SKU NUMBER', 'SHIPPED QUANTITY',
#        'INVOICE DATE', 'INVOICE NUMBER', 'CUSTOMER PART NUMBTER',
#        'CUSTOMER PURCHASE ORDER NUMBER', 'UNIT PRICE', 'EXTENDED PRICE',
#        'CSP L\n(Y/N)', 'CSP L\nPRICE\n', 'WA', 'PRODUCT DESCRIPTION',
#        'GRAINGER ITEM', 'BRAND NAME', 'PRODUCT CATEGORY',
#        'PRODUCT SUB-CATEGORY', 'SUB TRACK CODE', 'CRP', 'CONCAT_SKU'],
#       dtype='object')

# %%
df_combined = pd.concat([df_jan_feb_mar,df_apr_may,df_jun_jul,df_aug_sept,df_oct_nov,df_dec],sort=False,ignore_index=True)

# %%
df_combined
# Out:
#                              ACCOUNT NAME  STRATEGIC ACCOUNT DIVISION NAME  \
# 0                        SEAWORLD ORLANDO                         SEAWORLD
# 1          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 2          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 3          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 4          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 5          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 6          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 7                EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 8                EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 9                EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 10               EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# ...

# %%
df2 = pd.DataFrame(df_combined['STRATEGIC ACCOUNT DIVISION NAME'].unique())

# %%
import os
a = os.getcwd()

# %%
#a
# Out:
# '/Users/izzyshen/Desktop/IDR COMBINED 2019'

# %%
#os.path.expanduser("~/Desktop/IDR COMBINED 2019")

# %%
#writer2= pd.ExcelWriter("unique_name.xlsx")

# %%
#df2.to_excel(writer2,index=False)

# %%
df2
# Out:
#                                    0
# 0                           SEAWORLD
# 1          AMERICAN MEDICAL RESPONSE
# 2             EDWARD DON AND COMPANY
# 3                             GERDAU
# 4                  TMS INTERNATIONAL
# 5                             ATKORE
# 6                             NN INC
# 7    MOMENTIVE PERFORMANCE MATERIALS
# 8                    ALPHA PACKAGING
# 9                      VENTURA FOODS
# 10                           ASHLAND
# 11                     XPO LOGISTICS
# 12          BAKER HUGHES - CORPORATE
# 13                           SOLENIS
# 14               SDI, INC/COMMERCIAL
# 15                  ZENITH HOME CORP
# 16                        BRIGHTVIEW
# 17                       DHL EXPRESS
# 18                       TRANSCENDIA
# 19                  DHL SUPPLY CHAIN
# 20                SUEZ NORTH AMERICA
# 21                     GE APPLIANCES
# 22                             MACYS
# 23                            PACTIV
# ...

# %%
df2.to_csv("unique_name.csv",sep=",")

# %%
df_combined
# Out:
#                              ACCOUNT NAME  STRATEGIC ACCOUNT DIVISION NAME  \
# 0                        SEAWORLD ORLANDO                         SEAWORLD
# 1          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 2          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 3          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 4          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 5          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 6          AMERICAN MEDICAL RESPONSE EPRO        AMERICAN MEDICAL RESPONSE
# 7                EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 8                EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 9                EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# 10               EDWARD DON & COMPANY ILL           EDWARD DON AND COMPANY
# ...

# %%
df_combined.count()
# Out:
# ACCOUNT NAME                       4065506
# STRATEGIC ACCOUNT DIVISION NAME    4065506
# ACCOUNT NUMBER                     4065506
# SHIPPING CITY                      4065506
# SHIPPING STATE                     4065420
# Manufacturer Code                  4039349
# MANUFACTURER NAME                  4065496
# MANUFACTURER PART NUMBER           4063011
# PRODUCT GROUP DESCRIPTION          4065475
# SKU NUMBER                         4065506
# SHIPPED QUANTITY                   4065504
# INVOICE DATE                       4065506
# INVOICE NUMBER                     4065506
# CUSTOMER PART NUMBTER              1141713
# CUSTOMER PURCHASE ORDER NUMBER     4059393
# UNIT PRICE                         4065504
# EXTENDED PRICE                     4065506
# CSP L\n(Y/N)                       4065506
# CSP L\nPRICE\n                     3696625
# WA                                 4065506
# PRODUCT DESCRIPTION                4065501
# GRAINGER ITEM                      4065506
# ...

# %%
df_combined2 = df_combined.copy()

# %%
df_combined3 = df_combined2[df_combined2['CSP L\n(Y/N)']!='S']

# %%
df_combined4 = df_combined3[['STRATEGIC ACCOUNT DIVISION NAME','CONCAT_SKU','SHIPPED QUANTITY','EXTENDED PRICE']]

# %%
df_combined4
# Out:
#          STRATEGIC ACCOUNT DIVISION NAME CONCAT_SKU SHIPPED QUANTITY  \
# 0                               SEAWORLD     '2HPC7                1
# 1              AMERICAN MEDICAL RESPONSE     '2VEX5                1
# 2              AMERICAN MEDICAL RESPONSE     '3EEE6                1
# 3              AMERICAN MEDICAL RESPONSE     '2PLC7                2
# 4              AMERICAN MEDICAL RESPONSE    '22VA42                1
# 5              AMERICAN MEDICAL RESPONSE     '4TKG8                6
# 6              AMERICAN MEDICAL RESPONSE    '53YH97                1
# 7                 EDWARD DON AND COMPANY    '30RV25                1
# 8                 EDWARD DON AND COMPANY    '30RV26                1
# 9                 EDWARD DON AND COMPANY    '33RF07                1
# 10                EDWARD DON AND COMPANY     '3PY46                1
# 11                                GERDAU     '4TKD9                4
# 12                                GERDAU    '23Z013                2
# ...

# %%
#df5 = df_combined4.groupby(['STRATEGIC ACCOUNT DIVISION NAME','CONCAT_SKU']).count()

# %%
df8 = df_combined4.groupby(['STRATEGIC ACCOUNT DIVISION NAME','CONCAT_SKU']).agg({'SHIPPED QUANTITY':['sum','count'],'EXTENDED PRICE':'sum'})
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in f(self, **kwargs)
#    1256                     return self._cython_agg_general(
# -> 1257                         alias, alt=npfunc, **kwargs)
#    1258                 except AssertionError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     837         if len(output) == 0:
# --> 838             raise DataError('No numeric types to aggregate')
#     839
#
# DataError: No numeric types to aggregate
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-5f6cc2b4523b> in <module>
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-2df5975f13fb> in <module>
# ----> 1 df8
#
# NameError: name 'df8' is not defined

# %%
df5
# Out:
#                                             SHIPPED QUANTITY  EXTENDED PRICE
# STRATEGIC ACCOUNT DIVISION NAME CONCAT_SKU
#                                 '30HC10                    1               1
# 24 HR FITNESS                   '10A164                    1               1
#                                 '10A326                    1               1
#                                 '10A373                    3               3
#                                 '10A374                    1               1
#                                 '10A375                    2               2
#                                 '10A411                    1               1
#                                 '10A541                    1               1
#                                 '10A581                    1               1
#                                 '10A604                    1               1
#                                 '10A652                    1               1
# ...
